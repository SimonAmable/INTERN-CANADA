# %% [markdown]
# # Import Libraires

# %%
# %pip install openai
# %pip install python-dotenv
# %pip install selenium
# %pip install pymongo
# %pip install beautifulsoup4
# %pip install "pymongo[srv]"

# %%
# import some basic python libaries (operating system, regular expressions, time)
import time
from datetime import datetime
import json
import logging
import os
# import some selenium components to rememeneber by name
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import TimeoutException, NoSuchElementException, WebDriverException,NoAlertPresentException,StaleElementReferenceException

#import mongoDB, we may add additional databases in the future for better 

# from pymongo import MongoClient
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

from bs4 import BeautifulSoup
from dotenv import load_dotenv, find_dotenv

#import custom library

# %% [markdown]
# # Load ENViroment variables

# %%
load_dotenv()
# Get environment variables
email = os.getenv('GLASSDOOR_EMAIL')
password = os.getenv('GLASSDOOR_PASSWORD')
mongodb_atlas_uri = os.getenv('MONGODB_ATLAS_URI')

# %% [markdown]
# # Setup

# %%
# ---------------------------- THIS BLOCK CONNECTS TO MONGO DB ATLAS SRVER-------------------------------------------------------------


# Create a new client and connect to the server
client = MongoClient(mongodb_atlas_uri, server_api=ServerApi('1'))
# Send a ping to confirm a successful connection

try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
db = client["canadian_intership_database"]

# -----------------------------------------------------------------------------------------
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %% [markdown]
# PARAMETERS TO CUSTOMIZE

# %%
#Setup url
login_url = "https://www.glassdoor.ca/index.htm"
jobs_url = "https://www.glassdoor.ca/Job/index.htm"

# Create a connection to the running mongodb instance i have locally
# client = MongoClient("mongodb://localhost:27017")
# db = client["my_database"]

#Delete all documents in the collection before we start a new ingestions, switch to an approach that keeps all historical data once finished
collection = db['opportunities_glassdoor']
# result = collection.delete_many({})
# print(result.deleted_count, " documents deleted.")

timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S") 
#search term for glass door
job_search_input ="Intern"

# %%
collection.insert_one({"date-ingested-timestamp":timestamp, "status":"OK"})
# Out:
# InsertOneResult(ObjectId('6796ee38dcd2b6354236510b'), acknowledged=True)

# %% [markdown]
# # Functions

# %%
def handle_possible_popup(driver):
    """
    Function that safely handles possible popups that may appear on this page.

    Parameters:
        driver (WebDriver): The WebDriver object
    """    
    try:
        # Wait for the modal to appear and find the close button
        close_button = WebDriverWait(driver, 1).until(
            EC.element_to_be_clickable((By.XPATH, "//div[@role='dialog']//button[@class='CloseButton']"))
        )
        save_job_alert_button = WebDriverWait(driver, 1).until(
            EC.element_to_be_clickable((By.CSS_SELECTOR, 'button[data-test="job-alert-modal-cta-save"]'))
        )
        # Click the close button
        close_button.click()
        save_job_alert_button.click()
        print(f"Clicked the close or save button.")
    except (TimeoutException, NoSuchElementException):
        # No alert button found or unable to click it, safely pass
        print(f"no alert buton found or unable to click it, safely pass")

        pass
    except Exception as e:
        # Log the unexpected exception for debugging
        print(f"An unexpected error occurred trying to click the close button.")
        # print(f"An unexpected error occurred: {e}")
        pass

# def random_sleep(min_time=1, max_time=3):
#     time.sleep(random.uniform(min_time, max_time))


def close_overlay(driver, timeout=10):
    try:
        # Wait for the overlay to be present
        overlay = WebDriverWait(driver, timeout).until(
            EC.presence_of_element_located((By.CLASS_NAME, "modal_ModalOverlay__DXtn2"))
        )
        
        # Find and click the close button
        # Note: You may need to adjust this selector based on the actual structure of the overlay
        close_button = driver.find_element(By.CSS_SELECTOR, 'button[aria-label="Cancel"]')
        close_button.click()
        # overlay.click()
        # Wait for the overlay to disappear
        WebDriverWait(driver, timeout).until(
            EC.invisibility_of_element_located((By.CLASS_NAME, "modal_ModalOverlay__DXtn2"))
        )
        
        print("Overlay closed successfully")
    except TimeoutException:
        print("No overlay found or unable to close within the timeout period")
    except NoSuchElementException:
        print("Close button not found in the overlay")

# %% [markdown]
# # Data Ingestion

# %% [markdown]
# ## first Login

# %%
# Configure webdriver object and ActionsChain object
# do some extra bs so the website thinks we are a real person
# Configure Chrome options

options = Options()
options.headless = True
options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36")
options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_experimental_option('useAutomationExtension', False)
# options.add_argument('--proxy-server=http://your-proxy-server:port')
driver = webdriver.Chrome(options=options)

actions = ActionChains(driver)

# Open the website
driver.get(login_url)


#first we must login
# email_input = driver.find_element(By.CSS_SELECTOR, "input[type='email']")
email_input = WebDriverWait(driver, 5).until(EC.presence_of_element_located((By.ID, 'inlineUserEmail')))
# email_input.click()
email_input.send_keys(email)
email_input.send_keys(Keys.RETURN)

# random_sleep()
# submit_button = WebDriverWait(driver, 5).until(EC.presence_of_element_located((By.ID, "button[type='submit']")))
# submit_button.click()

time.sleep(5)
password_input = driver.find_element(By.ID, "inlineUserPassword")
# password_input = WebDriverWait(driver, 5).until(EC.presence_of_element_located((By.XPATH, "/html[1]/body[1]/div[2]/section[1]/div[2]/div[1]/div[1]/div[1]/div[1]/div[1]/div[1]/div[1]/form[1]/div[1]/div[1]/div[1]/div[1]/input[1]")))
# random_sleep()
time.sleep(2)

password_input.click()
password_input.send_keys(password)
password_input.send_keys(Keys.RETURN)
#HORAYYYYYYY we are logged in

# %% [markdown]
# # OPEN ALL JOBS AND GET DATA

# %%
#once logged in we can now search for jobs
time.sleep(8)
try:
    driver.get(jobs_url)
    time.sleep(3)
except Exception as e:
    print(f"Error occurred while navigating to {jobs_url}: {e}")
time.sleep(3)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 5
#       3 try:
#       4     driver.get(jobs_url)
# ----> 5     time.sleep(3)
#       6 except Exception as e:
#       7     print(f"Error occurred while navigating to {jobs_url}: {e}")
#
# KeyboardInterrupt:

# %%
# #Here we will search based on the variables earlier defined

# job_search = driver.find_element(By.CSS_SELECTOR, "input[placeholder='Find your perfect job']")
# job_search.click()
# job_search.clear()
# job_search.send_keys(job_search_input)
# time.sleep(2)

# location_search = driver.find_element(By.XPATH, "//input[@aria-labelledby='searchBar-location_label']")
# location_search.click()
# location_search.clear()
# location_search.send_keys("Canada")
# time.sleep(2)
# location_search.send_keys(Keys.RETURN)
# time.sleep(3)
# #The page should now be loaded with the search results

# close_overlay(driver)


# # First, find the 'Show More Jobs' button and click it until all jobs are open
# while True:
#     try:
#         show_more_jobs_button = driver.find_element(By.XPATH, "//button[@data-test='load-more']")
#         if show_more_jobs_button.is_displayed():
#             actions.move_to_element(show_more_jobs_button).perform()
#             show_more_jobs_button.click()
#             time.sleep(1)
#             handle_possible_popup(driver)
#         else:
#             break
#     except (NoSuchElementException, IndexError):
#         # If the button is not found, break the loop
#         print("No more 'Show More Jobs' button found.")
#         break
#     except Exception as e:
#         print(f"An unexpected error occurred: {e}")
#         break
# # All jobs are now open on the page
# time.sleep(2)

# # Get a clickable link to all the jobs on the page
# all_jobs = driver.find_elements(By.CLASS_NAME, "JobsList_jobListItem__wjTHv")
# links = driver.find_elements(By.XPATH, "//a[contains(@class, 'JobCard_trackingLink__GrRYn')]")
# print(f"Number of jobs found: {len(all_jobs)}")

# # Loop through all the jobs and extract the details
# for job in all_jobs:
#     try:

#         # Click each job
#         actions.move_to_element(job).perform()
#         #print(job.text)
#         time.sleep(1)
#         job.click()
#         time.sleep(1)
#         handle_possible_popup(driver)
#         time.sleep(1)


#         # Extract and proccees job details here
#         show_desc_button = WebDriverWait(driver, 5).until(EC.presence_of_element_located((By.CSS_SELECTOR, "button[class='JobDetails_showMore___Le6L'] span")))
#         show_desc_button.click()

#         time.sleep(2)
#         description = WebDriverWait(driver, 5).until(EC.presence_of_element_located((By.CLASS_NAME, "JobDetails_jobDetailsContainer__y9P3L")))
#         description_text = description.text
#         # print(description_text)
        
#         company_name = WebDriverWait(driver, 5).until(EC.presence_of_element_located((By.XPATH, "//h4[@aria-live='polite']")))
#         company_name_text = company_name.text
#         print(company_name_text)

#         position_title = WebDriverWait(driver, 5).until(EC.presence_of_element_located((By.XPATH, "//h1[@aria-live='polite']")))
#         position_title_text = position_title.text
#         print(position_title_text)

#         location = WebDriverWait(driver, 5).until(EC.presence_of_element_located((By.XPATH, "//div[@data-test='location']")))
#         location_text = location.text
#         print(location_text)

#         apply_button = WebDriverWait(driver, 5).until(EC.presence_of_element_located((By.CLASS_NAME, "JobDetails_applyButtonContainer__L36Bs")))
#         apply_button_text = apply_button.text
#         print(F"Apply link: {apply_button_text}")

#         salary = WebDriverWait(driver, 5).until(EC.presence_of_element_located((By.XPATH, "//body/div/div[@data-app-navigation-hidden-class='Page_hideNav__grCji']/div/div/div/div/div/section/section[1]/div[1]/div[1]")))
#         salary_text = salary.text
#         print(salary_text)
        
        
#         current_window = ""
#         if ("Apply on employer site" in apply_button_text ):
#             print("Apply on employer site found")
#             # Click the apply button, save url then close page
#             ActionChains(driver).key_down(Keys.CONTROL).click(apply_button).key_up(Keys.CONTROL).perform() #can be replaced with a normal click proabably
#             time.sleep(5)

#             #check for popups
#             try:
#                 skip_for_now_button = WebDriverWait(driver, 5).until(EC.presence_of_element_located((By.CSS_SELECTOR, 'button[data-test="skip-registration"]')))
#                 skip_for_now_button.click()
#                 print("Skip for now button found.")
#                 time.sleep(5)
#             except (NoSuchElementException, IndexError):
#                 print("No skip for now button found.")
#             except Exception as e:
#                 print(f"An unexpected error occurred: {e}")
#                 pass
#                 # if windows is opened save url and close
#             if (len(driver.window_handles) > 1):
#                 # Get the current window handle
#                 driver.switch_to.window(driver.window_handles[-1])
#                 current_window = driver.current_url
#                 # Switch to the new window
#                 # Close the current window
#                 driver.close()
#                 driver.switch_to.window(driver.window_handles[0])
#         else:
#             print ("Easy apply found, no link to apply")
                
        

#         # print (apply_button_text)
#         # print(current_window)
#         # print (description_text)
#         # Insert the job details into the database
#         data = {
#             "title": position_title_text,
#             "company": company_name_text,
#             "location": location_text,
#             "apply_link": current_window,
#             "description": description_text,
#             "timestamp": timestamp
#         }
#         print(data)
#         collection.insert_one(data)
#     except Exception as e:
#         print(f"Error occurred while processing a job: {e}")
        
        

# # Close driver
# time.sleep(2)
# driver.quit()
# Out:
# Overlay closed successfully
# no alert buton found or unable to click it, safely pass
# no alert buton found or unable to click it, safely pass
# no alert buton found or unable to click it, safely pass
# no alert buton found or unable to click it, safely pass
# no alert buton found or unable to click it, safely pass
# no alert buton found or unable to click it, safely pass
# no alert buton found or unable to click it, safely pass
# no alert buton found or unable to click it, safely pass
# no alert buton found or unable to click it, safely pass
# no alert buton found or unable to click it, safely pass
# no alert buton found or unable to click it, safely pass
# no alert buton found or unable to click it, safely pass
# no alert buton found or unable to click it, safely pass
# no alert buton found or unable to click it, safely pass
# no alert buton found or unable to click it, safely pass
# no alert buton found or unable to click it, safely pass
# no alert buton found or unable to click it, safely pass
# no alert buton found or unable to click it, safely pass
# no alert buton found or unable to click it, safely pass
# no alert buton found or unable to click it, safely pass
# no alert buton found or unable to click it, safely pass
# no alert buton found or unable to click it, safely pass
# no alert buton found or unable to click it, safely pass
# no alert buton found or unable to click it, safely pass
# no alert buton found or unable to click it, safely pass
# no alert buton found or unable to click it, safely pass
# no alert buton found or unable to click it, safely pass
# no alert buton found or unable to click it, safely pass
# no alert buton found or unable to click it, safely pass
# No more 'Show More Jobs' button found.
# Number of jobs found: 901
# no alert buton found or unable to click it, safely pass
# Smythe LLP
# Assurance CO-OP Student or Internships (Jan 2025) - Vancouver
# Vancouver
# Apply link: Apply on employer site
# The minimum salary is $53K and the max salary is $53K.
# $53K/yr (Employer est.)
# Vancouver
# Apply on employer site found
# An unexpected error occurred: Message:
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7EC48B5D2+29090]
# 	(No symbol) [0x00007FF7EC3FE689]
# 	(No symbol) [0x00007FF7EC2BB1CA]
# 	(No symbol) [0x00007FF7EC30EFD7]
# 	(No symbol) [0x00007FF7EC30F22C]
# 	(No symbol) [0x00007FF7EC3597F7]
# 	(No symbol) [0x00007FF7EC33672F]
# 	(No symbol) [0x00007FF7EC3565D9]
# 	(No symbol) [0x00007FF7EC336493]
# 	(No symbol) [0x00007FF7EC3009B1]
# 	(No symbol) [0x00007FF7EC301B11]
# 	GetHandleVerifier [0x00007FF7EC7A8C5D+3295277]
# 	GetHandleVerifier [0x00007FF7EC7F4843+3605523]
# 	GetHandleVerifier [0x00007FF7EC7EA707+3564247]
# 	GetHandleVerifier [0x00007FF7EC546EB6+797318]
# 	(No symbol) [0x00007FF7EC40980F]
# 	(No symbol) [0x00007FF7EC4053F4]
# 	(No symbol) [0x00007FF7EC405580]
# 	(No symbol) [0x00007FF7EC3F4A1F]
# 	BaseThreadInitThunk [0x00007FFE014D257D+29]
# 	RtlUserThreadStart [0x00007FFE027AAF28+40]
#
# {'title': 'Assurance CO-OP Student or Internships (Jan 2025) - Vancouver', 'company': 'Smythe LLP', 'location': 'Vancouver', 'apply_link': 'https://phf.tbe.taleo.net/phf04/ats/careers/v2/viewRequisition?org=SMYTHE&cws=45&rid=527', 'description': 'Smythe LLP\n3.1\nAssurance CO-OP Student or Internships (Jan 2025) - Vancouver\nVancouver\nApply on employer site\nApply on employer site\nAssurance CO-OP Student or Internships (Jan 2025) - Vancouver\nAt Smythe LLP (Smythe), we believe that each staff member is an individual and that your career path is driven by your own ambition. We provide year-round coaching and mentorship and offer a diverse learning environment for motivated individuals with a positive team-based approach.\nSmythe is excited to invite students to join our Assurance Practice Group for or positions commencing at our Vancouver, BC office in January 2025.\nDuring your co-op/internship experience with Smythe, you will:\nWork closely with a dedicated coach to guide you in your professional development and individual career growth;\nBecome proficient in completing compilations and reviews for privately-held companies in a wide variety of industries, including technology, real estate, mining, hospitality, not-for-profits and more;\nAttain the knowledge to prepare corporate, personal and other tax returns;\nWork directly with clients, including CEOs, CFOs, and Directors to develop strong client relationships;\nReceive comprehensive training and support toward your academic and professional success; and\nGain valuable skills and experiences to assist with reaching your full career potential.\nAt Smythe, we are committed to the development of our people. We offer ambitious individuals opportunities to challenge themselves and advance their careers not only on a technical front, but also in regard to business development and community support. Our culture is highly supportive and embraces diversity.\nTo apply for this role, login into our Career Centre Portal, click here and upload (in one PDF document and in this order) your cover letter, your resume, and your transcript(s). Applications lacking required documents will not be considered. Please address your application to Mahesh Nandwani, Senior Talent Acquisition Specialist. Click here to learn more about our co-op and Articling opportunities. The deadline to apply for this role is Sunday, September 15th, 2024 at 11:59pm.\nWe thank everyone for their interest in working at Smythe and for applying for this role. We\'ll be in touch with candidates who have been shortlisted for further consideration.\nJob Types: Full-time, Fixed term contract, Internship / Co-op\nContract length: 4 months\nPay: $53,000.00 per year\nAdditional pay:\nOvertime pay\nBenefits:\nCompany events\nEmployee assistance program\nWellness program\nSchedule:\nMonday to Friday\nWeekends as needed\nApplication question(s):\nAre you legally authorized to work for any employer in Canada?\nWork Location: In person\nShow less\nBase pay\nThe minimum salary is $53K and the max salary is $53K.\n$53K/yr (Employer est.)\nVancouver\nIf an employer includes a salary or salary range on their job, we display it as an "Employer Estimate". If a job has no salary data, Glassdoor displays a "Glassdoor Estimate" if available. To learn more about "Glassdoor Estimates," see our FAQ page.\nCompany overview\nSize\n201 to 500 Employees\nFounded\n1980\nType\nCompany - Private\nIndustry\nAccounting & Tax\nSector\nFinance\nRevenue\nUnknown / Non-Applicable\nSmythe LLP Ratings\n3.1\n56 %\nRecommend to a friend\n88 %\nApprove of CEO\nBob Sanghera, Larry Vicic\n18 Ratings\nCareer opportunities\n3.2\nComp and Benefits\n2.8\nCulture and values\n3.3\nSenior management\n3.1\nWork/Life Balance\n3.0\nSmythe LLP Reviews\nPros\n"Amazing people amazing culture great benefits hybrid working smythe summer days" (in 7 reviews)\n"basic and extended benefits" (in 4 reviews)\n"Leadership is flex to situations of people" (in 4 reviews)\n"Great people ...
# no alert buton found or unable to click it, safely pass
# A&B Rail | Universal Rail Systems Company
# Summer Student - Project Coordinator
# Saint-Rémi
# Apply link: Easy Apply
# The minimum salary is $20.00 and the max salary is $20.00.
# $20.00/hr (Employer est.)
# Saint-Rémi
# Easy apply found, no link to apply
# {'title': 'Summer Student - Project Coordinator', 'company': 'A&B Rail | Universal Rail Systems Company', 'location': 'Saint-Rémi', 'apply_link': '', 'description': 'A&B Rail | Universal Rail Systems Company\n3.8\nSummer Student - Project Coordinator\nSaint-Rémi\nEasy Apply\nEasy Apply\nSummer Student: Project Coordinator – Montreal, QC\nWHO WE ARE:\nAt A&B Rail Services Ltd | Universal Rail Systems Company our work is getting and keeping Canada’s railway operators in motion – safely and sustainably! We work coast-to-coast, in every railway sector, and on any size project. Our commitment is service excellence and offering our clients exceptional value. Within our team, we call this Doing It Right!\nA&B Rail is seeking a Summer Student: Project Coordinator to join our Quebec Project Team. Reporting to the Project Manager located in Montreal, QC.\nGeneral Purpose: Reporting to the Project Manager, the Project Coordinator is responsible for the accurate and timely completion of a variety of administrative tasks required to support the needs of the project teams, vendors and subcontractors. The position requires a strong team player with excellent communication, organizational and planning skills with initiative and the ability to work independently and juggle multiple deadlines.\nRequirements:\nWork with the Project Manager to establish a cost reporting system for all project components.\nMonitor daily, weekly and monthly labor, equipment, material and sub-trade costs.\nDevelop and maintain project schedule with the assistance of the Project Manager.\nEnsure that all technical aspects of the work conform to all applicable codes and standards.\nEnsure that all work is completed accurately (i.e. survey).\nPerforms general administrative and recordkeeping functions such as photocopying, filing, faxing and preparing and distributing correspondence\nMaintains various contact and distribution lists for the department or project\nAssist and monitors payroll functions\nComplete estimates review estimates and assists in costing.\nAssists in maintaining systems and procedures.\nAssists in contacting trades and suppliers, regarding invitations, pricing, addenda and tender/bid closings\nParticipates in meetings and records minutes\nEnsures all internal controls, processes and procedures are followed\nPerforms other related duties as assigned\nKnowledge:\nStrong interpersonal, communication and customer service skills\nStrong computer skills are required with proven proficiency in Microsoft Office (Word, Excel,PowerPoint, and Outlook)\nDemonstrated customer service focus\nAbility to multi-task, prioritize tasks and quickly adjust to a rapidly changing environment\nEffective and proven organizational skills to meet multiple deadlines and handle multiple tasks in a high pressure and demanding work environment\nAbility to work independently as well as in a team environment\nDemonstrate a high level of confidentiality\nJob Requirements:\nPost secondary education in progress\n0-1 years of construction experience\nFrench speaking, mandatory\nPlease send your resume and a cover letter quoting “Project Coordinator-Montreal” in the subject line to:\nStephanie Paget\nEmail: stephaniepaget@universalrail.com\nWe would like to thank all applicants for their interest but only those selected for an interview will be contacted.\nA&B Rail Services | Universal Rail Systems Company is an Equal Opportunity Employer.\n#EST\nJob Types: Full-time, Seasonal, Internship / Co-op\nPay: From $20.00 per hour\nWork Location: In person\nShow less\nBase pay\nThe minimum salary is $20.00 and the max salary is $20.00.\n$20.00/hr (Employer est.)\nSaint-Rémi\nIf an employer includes a salary or salary range on their job, we display it as an "Employer Estimate". If a job has no salary data, Glassdoor displays a "Glassdoor Estimate" if available. To learn more about "Glassdoor Estimates," see our FAQ page.\nCompany overview\nSize\n1001 to 5000 Employees\nFounded\n1965\nType\nSubs ...
# no alert buton found or unable to click it, safely pass
# AXYS Technologies Inc.
# Ocean Designer – Level 1 or Co-op
# Sidney
# Apply link: Apply on employer site
# The minimum salary is $67K and the max salary is $80K.
# $67K – $80K/yr (Glassdoor est.)
# $73K
# /yr Median
# Sidney
# Apply on employer site found
# An unexpected error occurred: Message:
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7EC48B5D2+29090]
# 	(No symbol) [0x00007FF7EC3FE689]
# 	(No symbol) [0x00007FF7EC2BB1CA]
# 	(No symbol) [0x00007FF7EC30EFD7]
# 	(No symbol) [0x00007FF7EC30F22C]
# 	(No symbol) [0x00007FF7EC3597F7]
# 	(No symbol) [0x00007FF7EC33672F]
# 	(No symbol) [0x00007FF7EC3565D9]
# 	(No symbol) [0x00007FF7EC336493]
# 	(No symbol) [0x00007FF7EC3009B1]
# 	(No symbol) [0x00007FF7EC301B11]
# 	GetHandleVerifier [0x00007FF7EC7A8C5D+3295277]
# 	GetHandleVerifier [0x00007FF7EC7F4843+3605523]
# 	GetHandleVerifier [0x00007FF7EC7EA707+3564247]
# 	GetHandleVerifier [0x00007FF7EC546EB6+797318]
# 	(No symbol) [0x00007FF7EC40980F]
# 	(No symbol) [0x00007FF7EC4053F4]
# 	(No symbol) [0x00007FF7EC405580]
# 	(No symbol) [0x00007FF7EC3F4A1F]
# 	BaseThreadInitThunk [0x00007FFE014D257D+29]
# 	RtlUserThreadStart [0x00007FFE027AAF28+40]
#
# {'title': 'Ocean Designer – Level 1 or Co-op', 'company': 'AXYS Technologies Inc.', 'location': 'Sidney', 'apply_link': 'https://axys.com/careers-junior-ocean-designer/', 'description': 'AXYS Technologies Inc.\n3.6\nOcean Designer – Level 1 or Co-op\nSidney\nApply on employer site\nApply on employer site\nAXYS Technologies (AXYS) is a global leader in developing innovative technologies for a variety of marine focused applications including offshore wind resource assessment, real-time weather forecasting, and environmental monitoring from the tropics to the poles. With over 50 years of experience in the design, manufacture, remote operational management, and service of these advanced oceanographic environmental monitoring systems, we have a dedicated team that has a passion for innovation and growth. Located in beautiful Sidney, British Columbia, AXYS is one of Vancouver Island’s most sought after career choices and offers competitive compensation and benefits to its staff.\nRole Outline:\nThe Product Development department requires a Ocean Designer – Level 1 or Co-op with a capacity for mooring simulation and design. You will work within a highly talented and motivated team to develop sophisticated environmental monitoring systems for projects world-wide.\nKey Responsibilities:\nDesigning\nSupport the design and development of metocean technology for a variety of marine applications, including floating, moored, seabed, mobile and platform mounted systems\nRun numerical simulations using ProteusDS to analyze mooring tension and platform stability.\nCarry out technical analysis on mooring parts and systems, including applying theoretical principles, numerical modeling, and physical testing.\nCompose mooring design reports that describe the survival characteristics of AXYS moorings.\nExpand simulation and analysis capabilities with Python scripting\nAid in platform selection and compose technical specifications for moorings and AXYS platforms in response to project RFQs.\nWork with and manage 3rd party companies supporting new designs, design testing and technical reviews.\nProduce assembly documents, work instructions, technical reports and system manuals as required to support product assembly, operation, and life-cycle management.\nProvide support to field services, production, sales, and customer service.\nEnsure project requirements are clearly identified.\nMaintain communication of design status, risks, and changes with team lead and project stakeholders.\n\n\nDepartment Development\n\nAssist with monitoring and maintaining processes for the department under ISO 9001:2015.\nLead department strategic initiatives as assigned.\nAssist with information capture for department capital budget & resources.\nGeneral Requirements\nMinimum BEng in Mechanical, Coastal or Ocean Engineering, Physical Oceanography, Computational Fluid Dynamics or other scientific disciplines dealing with numerical modelling (e.g. Physics, Mathematics).\nExperience in completing design projects, delivering systems for the marine environment.\nExcellent written and verbal communication skills.\nHolds a thorough understanding of product design principles and standards.\nCommands excellent problem solving and deduction skills.\nWillingness to take responsibility and driven to meet deadlines.\n\nTechnical Requirements\nExperienced with running and validating simulation results.\nExperienced with developing scripts programs in Python.\nFamiliar with principles of fluid dynamics, hydrostatic and hydrodynamic forces on floating structures.\nFamiliar knowledge of mechanical, material and reliability design principles.\nFamiliar with 3DCAD software; part, assemblies and file management.\nExperienced with or desire to develop project management basics.\n\nAdditional Ideal Requirements\nExperienced in the creation of professional level design documentation including requirements, assembly drawings, fabrication drawings, bills of material, test plans, FMEA, work instr ...
# no alert buton found or unable to click it, safely pass
# Error occurred while processing a job: Message:
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7EC48B5D2+29090]
# 	(No symbol) [0x00007FF7EC3FE689]
# 	(No symbol) [0x00007FF7EC2BB1CA]
# 	(No symbol) [0x00007FF7EC30EFD7]
# 	(No symbol) [0x00007FF7EC30F22C]
# 	(No symbol) [0x00007FF7EC3597F7]
# 	(No symbol) [0x00007FF7EC33672F]
# 	(No symbol) [0x00007FF7EC3565D9]
# 	(No symbol) [0x00007FF7EC336493]
# 	(No symbol) [0x00007FF7EC3009B1]
# 	(No symbol) [0x00007FF7EC301B11]
# 	GetHandleVerifier [0x00007FF7EC7A8C5D+3295277]
# 	GetHandleVerifier [0x00007FF7EC7F4843+3605523]
# 	GetHandleVerifier [0x00007FF7EC7EA707+3564247]
# 	GetHandleVerifier [0x00007FF7EC546EB6+797318]
# 	(No symbol) [0x00007FF7EC40980F]
# 	(No symbol) [0x00007FF7EC4053F4]
# 	(No symbol) [0x00007FF7EC405580]
# 	(No symbol) [0x00007FF7EC3F4A1F]
# 	BaseThreadInitThunk [0x00007FFE014D257D+29]
# 	RtlUserThreadStart [0x00007FFE027AAF28+40]
#
# no alert buton found or unable to click it, safely pass
# Carter Hearing
# Registered Hearing Practitioner, RHIP or Conditional Hearing Practitioner
# Chilliwack
# Apply link: Easy Apply
# The minimum salary is $32.00 and the max salary is $45.00.
# $32.00 – $45.00/hr (Employer est.)
# $38.50
# /hr Median
# Chilliwack
# Easy apply found, no link to apply
# {'title': 'Registered Hearing Practitioner, RHIP or Conditional Hearing Practitioner', 'company': 'Carter Hearing', 'location': 'Chilliwack', 'apply_link': '', 'description': 'Carter Hearing\nRegistered Hearing Practitioner, RHIP or Conditional Hearing Practitioner\nChilliwack\nEasy Apply\nEasy Apply\nRegistered Hearing Instrument Practitioner Carter Hearing LTD (Private Practice) - Chilliwack/Sardis. Great opportunity to work at a private practice! We focus on improving the quality of life through better hearing. Work with a fun and enthusiastic team!?We have a full-time opportunity for a Licensed Hearing Care Professional!\nWe are currently looking for a motivated and patient driven Hearing Instrument Practitioners/ Audiologists/ Student Practitioners for clinic consultant position in Merritt/Lillooeet Clinics\nIf you possess the following skills, you are the candidate we are looking for:\nA passion to provide extraordinary levels of customer service.\nThe ability to provide the best experience and highest quality care for our clients.\nThe drive to lead and enthusiasm to motivate your team to meet sales goals.\nStrong technical skills with audiometric equipment and computers.\nStrong communication and sales abilities are required.\nLove of variety, travelling at times to different clinics and community health events.\nA keen ability to interact professionally with clients and team members is mandatory.\nRegistration with the College of Speech and Hearing Health Professionals of BC in accordance with professional requirements for an AUD/HIP or HIP.\nOur employees are our most important resource. We offer a unique and attractive competitive total compensation package.\nSend us your resume and cover letter.\nJob Types: Full-time, Part-time, Internship / Co-op\nPay: $32.00-$45.00 per hour\nAdditional pay:\nBonus pay\nBenefits:\nDental care\nExtended health care\nLife insurance\nVision care\nSchedule:\n8 hour shift\nWork Location: In person\nShow less\nBase pay range\nThe minimum salary is $32.00 and the max salary is $45.00.\n$32.00 – $45.00/hr (Employer est.)\n$38.50\n/hr Median\nChilliwack\nIf an employer includes a salary or salary range on their job, we display it as an "Employer Estimate". If a job has no salary data, Glassdoor displays a "Glassdoor Estimate" if available. To learn more about "Glassdoor Estimates," see our FAQ page.', 'timestamp': '2024-09-08 11:29:04'}
# no alert buton found or unable to click it, safely pass
# BC Hydro
# Co-op Student - Commerce, Business Admin, Data Analytics - January 2025
# British Columbia
# Apply link: Apply on employer site
# The minimum salary is $4K and the max salary is $5K.
# $4K – $5K/mo (Employer est.)
# $4K
# /mo Median
# British Columbia
# Apply on employer site found
# An unexpected error occurred: Message:
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7EC48B5D2+29090]
# 	(No symbol) [0x00007FF7EC3FE689]
# 	(No symbol) [0x00007FF7EC2BB1CA]
# 	(No symbol) [0x00007FF7EC30EFD7]
# 	(No symbol) [0x00007FF7EC30F22C]
# 	(No symbol) [0x00007FF7EC3597F7]
# 	(No symbol) [0x00007FF7EC33672F]
# 	(No symbol) [0x00007FF7EC3565D9]
# 	(No symbol) [0x00007FF7EC336493]
# 	(No symbol) [0x00007FF7EC3009B1]
# 	(No symbol) [0x00007FF7EC301B11]
# 	GetHandleVerifier [0x00007FF7EC7A8C5D+3295277]
# 	GetHandleVerifier [0x00007FF7EC7F4843+3605523]
# 	GetHandleVerifier [0x00007FF7EC7EA707+3564247]
# 	GetHandleVerifier [0x00007FF7EC546EB6+797318]
# 	(No symbol) [0x00007FF7EC40980F]
# 	(No symbol) [0x00007FF7EC4053F4]
# 	(No symbol) [0x00007FF7EC405580]
# 	(No symbol) [0x00007FF7EC3F4A1F]
# 	BaseThreadInitThunk [0x00007FFE014D257D+29]
# 	RtlUserThreadStart [0x00007FFE027AAF28+40]
#
# {'title': 'Co-op Student - Commerce, Business Admin, Data Analytics - January 2025', 'company': 'BC Hydro', 'location': 'British Columbia', 'apply_link': 'https://app.bchydro.com/sap/bc/webdynpro/sap/hrrcf_a_posting_apply?PARAM=cG9zdF9pbnN0X2d1aWQ9M0ExODRDMTRBMTBCMUVERjk5Q0E5NDJGNEY4N0M2MzUmY2FuZF90eXBlPUVYVA%3d%3d&sap-theme=sap_belize&sap-client=100&sap-language=EN&sap-accessibility=X&sap-ie=Edge&sap-wd-configid=ZHRRCF_A_UNREG_JOB_SEARCH#', 'description': 'BC Hydro\n3.9\nCo-op Student - Commerce, Business Admin, Data Analytics - January 2025\nBritish Columbia\nApply on employer site\nApply on employer site\nA workplace powered by you\nAt BC Hydro, we’re working towards creating a cleaner and more sustainable future for all British Columbians and need\npeople like you to help us. A career at BC Hydro is meaningful and provides you the opportunity to be part of a talented,\ninclusive, and diverse team. We offer a healthy work-life balance, competitive wages, a comprehensive benefits package,\nand training opportunities to support you in your career growth. We\'re proud to be ranked as one of B.C.\'s Top Employers\nand one of Canada\'s Best Diversity Employers.\n\nWe invite you to join us as we build an even cleaner B.C. We welcome applications from all qualified job seekers. If you’re a\nperson with a disability, please let us know as adjustments can be made to help support you in your application process.\nCo-op Student - Commerce, Business Admin, Data Analytics - January 2025\nNumber of positions: 1 Job Location: Edmonds 14\nEmployment type: Co-Op Region: Lower Mainland\nHours of work: Full-time (37.5 hrs/wk) Flexible Work Role: Hybrid\nAnnual salary: 1,792.24 - $2,257.45 biweekly\nWhat you\'ll do\nCandidate selection, interviews and hiring will take place continuously from this single posting – this means while there is a\nclosing date listed, hiring managers will regularly review applications submitted shortly after the posting is live in your Co-op\nsystem. So, we recommend you apply early to get the best visibility from all hiring managers.\n\nStudents invited to interview will receive more detail of the specific position during the interview.\n\nWe are looking for team-oriented Co-op students who demonstrates strong research, analytical, stakeholder engagement\nand problem-solving skills. As a member of one of BC Hydro’s business unit teams, the candidates will be responsible for\nsupporting various analytical research projects and initiatives.\n\nKey responsibilities:\n\nActivities may include: conducting business analysis; initiating and engaging with stakeholders; gathering, preparing and\npresenting data for review; drafting reports and findings; record management support; project tracking; and supporting\nproject teams, as needed.\n\nThe student will learn about the utility industry and be given the opportunity to develop skillsets in the following areas:\nprocess improvement, data analysis and stakeholder engagement presenting and facilitating information and findings,\nproject management, developing analytical/strategic thinking, and problem solving.\nWhat you bring\nTo qualify as a candidate, individual\'s must be enrolled in the Co-op Program and have yet to graduate from a recognized\npost-secondary institution in Canada.\nStrong research, analytical, project management, report writing and presentation skills.\nExperience and interest in business analysis projects, as well as analyzing and presenting data and findings to project\nteam members.\nExcellent working knowledge of MS Office suite (Word, Excel, Visio, Powerpoint).\nStrong organizational, time management, interpersonal and communication (both written and oral) skills and the ability to\nwork efficiently, independently and in a team environment.\nMust have completed accounting courses and have working experiences/courses with Power Query/Power BI, Tableau or\nprogramming languages such as Python or R.\nWhat we offer\nAs a condition of employment at BC H ...
# no alert buton found or unable to click it, safely pass
# Smythe LLP
# PRIVCO Articling Student (September 2025) - Nanaimo
# Nanaimo
# Apply link: Apply on employer site
# The minimum salary is $54K and the max salary is $54K.
# $54K/yr (Employer est.)
# Nanaimo
# Apply on employer site found
# An unexpected error occurred: Message:
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7EC48B5D2+29090]
# 	(No symbol) [0x00007FF7EC3FE689]
# 	(No symbol) [0x00007FF7EC2BB1CA]
# 	(No symbol) [0x00007FF7EC30EFD7]
# 	(No symbol) [0x00007FF7EC30F22C]
# 	(No symbol) [0x00007FF7EC3597F7]
# 	(No symbol) [0x00007FF7EC33672F]
# 	(No symbol) [0x00007FF7EC3565D9]
# 	(No symbol) [0x00007FF7EC336493]
# 	(No symbol) [0x00007FF7EC3009B1]
# 	(No symbol) [0x00007FF7EC301B11]
# 	GetHandleVerifier [0x00007FF7EC7A8C5D+3295277]
# 	GetHandleVerifier [0x00007FF7EC7F4843+3605523]
# 	GetHandleVerifier [0x00007FF7EC7EA707+3564247]
# 	GetHandleVerifier [0x00007FF7EC546EB6+797318]
# 	(No symbol) [0x00007FF7EC40980F]
# 	(No symbol) [0x00007FF7EC4053F4]
# 	(No symbol) [0x00007FF7EC405580]
# 	(No symbol) [0x00007FF7EC3F4A1F]
# 	BaseThreadInitThunk [0x00007FFE014D257D+29]
# 	RtlUserThreadStart [0x00007FFE027AAF28+40]
#
# {'title': 'PRIVCO Articling Student (September 2025) - Nanaimo', 'company': 'Smythe LLP', 'location': 'Nanaimo', 'apply_link': 'https://phf.tbe.taleo.net/phf04/ats/careers/v2/viewRequisition?org=SMYTHE&cws=45&rid=535', 'description': 'Smythe LLP\n3.1\nPRIVCO Articling Student (September 2025) - Nanaimo\nNanaimo\nApply on employer site\nApply on employer site\nPRIVCO Articling Student (September 2025) - Nanaimo\nAt Smythe LLP (Smythe), we believe that each staff member is an individual and that your career path is driven by your own ambition. We provide year-round coaching and mentorship and offer a diverse learning environment for motivated individuals with a positive team-based approach.\nSmythe is excited to invite students to join our Private Companies (PRIVCO) Practice Group for full-time Articling positions commencing at our Nanaimo, BC office in September 2025. In order to be considered for this full-time articling position, you must have fulfilled all prerequisites (CPA PREP) and be eligible to commence the CPA PEP program while employed with us. Please note that this program is pre-approved within the CPA’s ACT (Assurance, Compilation, Taxes) Pathway.\nDuring your articling experience with Smythe, you will:\nWork closely with a dedicated coach to guide you in your professional development and individual career growth;\nBecome proficient in completing compilations and reviews for privately-held companies in a wide variety of industries, including technology, real estate, hospitality and more;\nAttain the knowledge to prepare corporate, personal and other tax returns;\nWork directly with clients including CEOs, CFOs and Directors to develop strong client relationships;\nReceive comprehensive training and support towards your academic and professional success; and\nGain valuable skills and experiences to assist with reaching your full career potential.\nSmythe is committed to the development of our people. We offer ambitious individuals opportunities to challenge themselves and advance their careers not only on a technical front but also in regard to business development and community support. Our culture is highly supportive and embraces diversity.\nTo apply for this role, login into our Career Centre Portal, click here and upload (in one PDF document and in this order) your cover letter, your resume, and your transcript(s). Applications lacking required documents will not be considered. Please address your application to Mahesh Nandwani, Senior Talent Acquisition Specialist. Click here to learn more about our co-op and Articling opportunities. The deadline to apply for this role is Sunday, September 15th, 2024 at 11:59pm.\nWe thank everyone for their interest in working at Smythe LLP and for applying to our role. We\'ll be in touch with candidates who have been shortlisted for further consideration.\nJob Types: Full-time, Permanent\nPay: From $54,000.00 per year\nAdditional pay:\nOvertime pay\nBenefits:\nCompany events\nDental care\nEmployee assistance program\nExtended health care\nLife insurance\nPaid time off\nTuition reimbursement\nVision care\nWellness program\nSchedule:\n8 hour shift\nDay shift\nMonday to Friday\nMorning shift\nOvertime\nWeekends as needed\nApplication question(s):\nAre you legally authorized to work for any employer in Canada?\nWork Location: In person\nShow less\nBase pay\nThe minimum salary is $54K and the max salary is $54K.\n$54K/yr (Employer est.)\nNanaimo\nIf an employer includes a salary or salary range on their job, we display it as an "Employer Estimate". If a job has no salary data, Glassdoor displays a "Glassdoor Estimate" if available. To learn more about "Glassdoor Estimates," see our FAQ page.\nCompany overview\nSize\n201 to 500 Employees\nFounded\n1980\nType\nCompany - Private\nIndustry\nAccounting & Tax\nSector\nFinance\nRevenue\nUnknown / Non-Applicable\nSmythe LLP Ratings\n3.1\n56 %\nRecommend to a friend\n88 %\nApprove of CEO\nBob Sanghera, Larry Vicic\n18 Ratings\nCareer oppor ...
# no alert buton found or unable to click it, safely pass
# NRT Technology Corp.
# Mobile Content Designer Assistant Co-op
# Toronto
# Apply link: Easy Apply
# The minimum salary is $87K and the max salary is $137K.
# $87K – $137K/yr (Glassdoor est.)
# $109K
# /yr Median
# Toronto
# Easy apply found, no link to apply
# {'title': 'Mobile Content Designer Assistant Co-op', 'company': 'NRT Technology Corp.', 'location': 'Toronto', 'apply_link': '', 'description': 'NRT Technology Corp.\n3.2\nMobile Content Designer Assistant Co-op\nToronto\nEasy Apply\nEasy Apply\nAbout NRT\nNRT is one of the 50 Best Managed Companies, and we’re looking for a dynamic candidate who is motivated and passionate about working for a FinTech leader!\n\nNRT provides next-generation commerce and information-enabling experiences for enterprise customers around the world. Our solutions include secure payment systems, specialized financial and marketing kiosks, AML compliance tracking and reporting tools, digital gamification and mobile experiences, intelligent table game platforms, credit/marker information services and electronic marker solutions. We work with hundreds of casinos throughout North and South America, Asia and beyond.\n\nWe offer a competitive salary, group benefits (health, vision, dental and life insurances), career advancement opportunities, and an exciting environment. Individual and creative contributions to our company objectives are highly encouraged and recognized. You can read more about us at: www.nrttech.com\n\nReporting to the Lead UX/UI Designer, the Mobile Content Designer Assistant Co-op’s primary mandate is to collaborate with our UX/UI designers, content developers to craft engaging and user-friendly content for our mobile applications.\n\nResponsibilities\n\nAssist in designing and developing content for mobile applications.\nCollaborate with UX/UI designers to ensure content aligns with the overall design and user experience strategy.\nSupport the creation of wireframes, prototypes, and mockups for new features and content.\nConduct user research and usability testing to gather feedback and make informed design decisions.\nMaintain content quality and consistency across mobile platforms, adhering to brand guidelines and standards.\nWork closely with developers to implement content effectively within the app.\nAssist in optimizing content for different devices, screen sizes, and operating systems.\nCoordinate with Application Release team to ensure the UI/UX and content meet the Apple App Store and Google Play Store requirements and policies.\nPerform regression tests and submit the apps to the stores.\nStay updated with the latest mobile content trends, best practices, and industry standards.\nQualifications\nCurrently pursuing a degree in Computer Science, UX/UI Design, or a related field.\nStrong understanding of mobile design principles, user experience, and content strategy.\nProficiency in design tools such as Adobe Creative Suite (Photoshop, Illustrator, XD), Figma, or Sketch.\nFamiliarity with HTML, CSS, and basic coding for mobile interfaces is a plus.\nExcellent communication skills and attention to detail.\nAbility to work collaboratively in a team environment and manage multiple projects.\nThis job is funded by the Government of Canada as advertised in the job posting. To be eligible for this position, you must be a Canadian citizen, permanent resident or a protected person defined by the Immigration and Refugee Protection Act.\n\nNRT would like to thank all applicants for applying, but only those applicants best suited for the position will be contacted. NRT is an equal opportunity employer. It is NRT’s policy to recruit and select applicants for employment solely on the basis of their qualifications, with emphasis on selecting the best-qualified person for the. NRT does not discriminate against applicants based on race, color, religion, sex, sexual orientation, national origin, or disability or any other status or condition protected by applicable law. NRT welcomes and encourages applications from all. Accommodations are available on request for candidates taking part in all aspects of the selection process. If you are selected for this position, please notify the HR team member for reasonable accommodation.\nShow less\nBase  ...
# no alert buton found or unable to click it, safely pass
# BC Hydro
# Co-op Student - Library/Archive - January 2025
# British Columbia
# Apply link: Apply on employer site
# The minimum salary is $4K and the max salary is $5K.
# $4K – $5K/mo (Employer est.)
# $4K
# /mo Median
# British Columbia
# Apply on employer site found
# An unexpected error occurred: Message:
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7EC48B5D2+29090]
# 	(No symbol) [0x00007FF7EC3FE689]
# 	(No symbol) [0x00007FF7EC2BB1CA]
# 	(No symbol) [0x00007FF7EC30EFD7]
# 	(No symbol) [0x00007FF7EC30F22C]
# 	(No symbol) [0x00007FF7EC3597F7]
# 	(No symbol) [0x00007FF7EC33672F]
# 	(No symbol) [0x00007FF7EC3565D9]
# 	(No symbol) [0x00007FF7EC336493]
# 	(No symbol) [0x00007FF7EC3009B1]
# 	(No symbol) [0x00007FF7EC301B11]
# 	GetHandleVerifier [0x00007FF7EC7A8C5D+3295277]
# 	GetHandleVerifier [0x00007FF7EC7F4843+3605523]
# 	GetHandleVerifier [0x00007FF7EC7EA707+3564247]
# 	GetHandleVerifier [0x00007FF7EC546EB6+797318]
# 	(No symbol) [0x00007FF7EC40980F]
# 	(No symbol) [0x00007FF7EC4053F4]
# 	(No symbol) [0x00007FF7EC405580]
# 	(No symbol) [0x00007FF7EC3F4A1F]
# 	BaseThreadInitThunk [0x00007FFE014D257D+29]
# 	RtlUserThreadStart [0x00007FFE027AAF28+40]
#
# {'title': 'Co-op Student - Library/Archive - January 2025', 'company': 'BC Hydro', 'location': 'British Columbia', 'apply_link': 'https://app.bchydro.com/sap/bc/webdynpro/sap/hrrcf_a_posting_apply?PARAM=cG9zdF9pbnN0X2d1aWQ9M0ExODRDMTRBMTBCMUVERjk5Q0FEMDM5MjdGNUM1REImY2FuZF90eXBlPUVYVA%3d%3d&sap-theme=sap_belize&sap-client=100&sap-language=EN&sap-accessibility=X&sap-ie=Edge&sap-wd-configid=ZHRRCF_A_UNREG_JOB_SEARCH#', 'description': 'BC Hydro\n3.9\nCo-op Student - Library/Archive - January 2025\nBritish Columbia\nApply on employer site\nApply on employer site\nA workplace powered by you\nAt BC Hydro, we’re working towards creating a cleaner and more sustainable future for all British Columbians and need\npeople like you to help us. A career at BC Hydro is meaningful and provides you the opportunity to be part of a talented,\ninclusive, and diverse team. We offer a healthy work-life balance, competitive wages, a comprehensive benefits package,\nand training opportunities to support you in your career growth. We\'re proud to be ranked as one of B.C.\'s Top Employers\nand one of Canada\'s Best Diversity Employers.\n\nWe invite you to join us as we build an even cleaner B.C. We welcome applications from all qualified job seekers. If you’re a\nperson with a disability, please let us know as adjustments can be made to help support you in your application process.\nCo-op Student - Library/Archive - January 2025\nNumber of positions: 1 Job Location: Edmonds Annex - W3\nEmployment type: Co-Op Region: Lower Mainland\nHours of work: Full-time (37.5 hrs/wk) Flexible Work Role: Hybrid\nAnnual salary: $1,792.24 - $2,257.45 biweekly\nWhat you\'ll do\nCandidate selection, interviews and hiring will take place continuously - this means while there is a closing date listed, hiring\nmanager will regularly review applications submitted shortly after the posting is live in your Co-op system. So, we\nrecommend you apply early!\n\nThis role is located at our Edmonds office in Burnaby.\n\nDigitization Librarian or Archivist\n\nThe goal of this position is to digitize a significant component of BC Hydro\'s Historical Photograph Collection.\n\nDuties and Responsibilities:\nThe co-op student will digitize BC Hydro\'s Historical Photograph Collection using a Epson flatbed scanner.\nPerform quality control checks on digital files\nProcess the digitized items using Adobe Photoshop\nCreate metadata for these digital objects\nWork with the Technical Services/Cataloguing Librarian to create and review scanning procedures\nThe co-op student may be asked to perform other duties related to the operation of a special library & archives\n\nBy the end of the project, the co-op student will gain experience in: working in a corporate library & archives; digitizing\nfragile materials; working with a flatbed scanner; using photoshop; and writing procedures.\nWhat you bring\nTo qualify as a candidate, individuals must be enrolled in a Co-op Program and have yet to graduate from a recognized\npost-secondary institution in Canada.\nStrong working knowledge of MS Office products (Word, Excel, PowerPoint, Outlook, etc.)\nStrong communication skills, highly motivated and results oriented.\n\nDigitization Librarian or Archivist\n\nThe ideal candidate for the digitization position has:\nExperience with and/or completed coursework in metadata and metadata standards (Dublin Core, MARC;\nCompleted coursework in preservation, metadata, or digital collections;\nWorking knowledge of handling archives, rare books, and/or special collections;\nWorking knowledge of, and experience with scanning software and hardware;\nWorking knowledge of, and experience with MS Office and Photoshop;\nWorking knowledge of metadata standards (Dublin Core, MARC);\nOutstanding oral and written communication and organizational skills;\nAccuracy and attention to detail;\nThe ability to follow and carry out instructions;\nIs enrolled in the MAS, dual or MLIS program.\nWhat we offer\nAs a condition of employme ...
# no alert buton found or unable to click it, safely pass
# BC Hydro
# Co-op Student – Meter Network Operations (Engineering, Data Science, Computer Sci)- January 2025
# Fraser
# Apply link: Apply on employer site
# The minimum salary is $4K and the max salary is $5K.
# $4K – $5K/mo (Employer est.)
# $4K
# /mo Median
# Fraser
# Apply on employer site found
# An unexpected error occurred: Message:
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7EC48B5D2+29090]
# 	(No symbol) [0x00007FF7EC3FE689]
# 	(No symbol) [0x00007FF7EC2BB1CA]
# 	(No symbol) [0x00007FF7EC30EFD7]
# 	(No symbol) [0x00007FF7EC30F22C]
# 	(No symbol) [0x00007FF7EC3597F7]
# 	(No symbol) [0x00007FF7EC33672F]
# 	(No symbol) [0x00007FF7EC3565D9]
# 	(No symbol) [0x00007FF7EC336493]
# 	(No symbol) [0x00007FF7EC3009B1]
# 	(No symbol) [0x00007FF7EC301B11]
# 	GetHandleVerifier [0x00007FF7EC7A8C5D+3295277]
# 	GetHandleVerifier [0x00007FF7EC7F4843+3605523]
# 	GetHandleVerifier [0x00007FF7EC7EA707+3564247]
# 	GetHandleVerifier [0x00007FF7EC546EB6+797318]
# 	(No symbol) [0x00007FF7EC40980F]
# 	(No symbol) [0x00007FF7EC4053F4]
# 	(No symbol) [0x00007FF7EC405580]
# 	(No symbol) [0x00007FF7EC3F4A1F]
# 	BaseThreadInitThunk [0x00007FFE014D257D+29]
# 	RtlUserThreadStart [0x00007FFE027AAF28+40]
#
# {'title': 'Co-op Student – Meter Network Operations (Engineering, Data Science, Computer Sci)- January 2025', 'company': 'BC Hydro', 'location': 'Fraser', 'apply_link': 'https://app.bchydro.com/sap/bc/webdynpro/sap/hrrcf_a_posting_apply?PARAM=cG9zdF9pbnN0X2d1aWQ9M0ExODRDMTRBMTBCMUVERjk5Q0FDMDJDRjZEOUM1MzAmY2FuZF90eXBlPUVYVA%3d%3d&sap-theme=sap_belize&sap-client=100&sap-language=EN&sap-accessibility=X&sap-ie=Edge&sap-wd-configid=ZHRRCF_A_UNREG_JOB_SEARCH#', 'description': 'BC Hydro\n3.9\nCo-op Student – Meter Network Operations (Engineering, Data Science, Computer Sci)- January 2025\nFraser\nApply on employer site\nApply on employer site\nA workplace powered by you\nAt BC Hydro, we’re working towards creating a cleaner and more sustainable future for all British Columbians and need\npeople like you to help us. A career at BC Hydro is meaningful and provides you the opportunity to be part of a talented,\ninclusive, and diverse team. We offer a healthy work-life balance, competitive wages, a comprehensive benefits package,\nand training opportunities to support you in your career growth. We\'re proud to be ranked as one of B.C.\'s Top Employers\nand one of Canada\'s Best Diversity Employers.\n\nWe invite you to join us as we build an even cleaner B.C. We welcome applications from all qualified job seekers. If you’re a\nperson with a disability, please let us know as adjustments can be made to help support you in your application process.\nCo-op Student – Meter Network Operations (Engineering, Data Science, Computer Sci)- January 2025\nNumber of positions: 1 Job Location: Fraser Vly Office\nEmployment type: Co-Op Region: Lower Mainland\nHours of work: Full-time (37.5 hrs/wk) Flexible Work Role: Hybrid\nAnnual salary: $1,792.24 - $2,257.45 biweekly\nWhat you\'ll do\nCandidate selection, interviews and hiring will take place continuously - this means while there is a closing date listed, hiring\nmanager will regularly review applications submitted shortly after the posting is live in your Co-op system. So, we\nrecommend you apply early!\n\nThe location for this position is our Fraser Valley Office (FVO) in Langley.\n\nWe are looking for team-oriented, Co-op students who demonstrates strong communications, interpersonal, analytical,\nand problem-solving skills.\n\nWorking with Meter Network Operations team may include: Monitoring, operating and troubleshooting meters and\ncommunications devices and their respective communications networks, providing first line telephone support and using\ndata to support decisions. Tasks will be assigned based on the needs of the department and strengths of the student.\n\nThe student will learn about the utility industry and will be given the opportunity to develop his/her communications skills,\nsoftware skills and professional judgement.\nWhat you bring\nTo qualify as a candidate, individual\'s must be enrolled in the Co-op Program and have yet to graduate from a recognized\npost-secondary institution in Canada.\n\nUndergraduate students working on their Degree/Diploma in Engineering/Applied Science; Data Science or Computer and\nInformation Systems; Technologist programs or equivalent are preferred. Previous work experience is an asset.\n\nStrong analytical skills, combined with good judgement and ability to learn quickly.\n\nStrong working knowledge of Microsoft Products (Word, Excel, PowerPoint, PowerBI). Knowledge of SQL and a\nvisualisation tool such as Tableau would be an asset. A good candidate will be confident at learning new software and\nindustry specific tools.\n\nStrong interpersonal and communication (both written and oral) skills are an asset and the ability to work efficiently,\nindependently and in a team environment.\n\nStrong attention to detail.\n\nSome Electrical Utility knowledge would be preferred.\nWhat we offer\nAs a condition of employment at BC Hydro, a background check clearance will be required.\n\nThis position is for a four month work term with a potential to extend  ...
# no alert buton found or unable to click it, safely pass
# CaptiveAire
# Inside Sales Intern
# Mississauga
# Apply link: Easy Apply
# Size
# 1001 to 5000 Employees
# Founded
# 1976
# Type
# Company - Private
# Industry
# Machinery Manufacturing
# Sector
# Manufacturing
# Revenue
# $500 million to $1 billion (USD)
# Easy apply found, no link to apply
# ...
# no alert buton found or unable to click it, safely pass
# Desjardins
# Internship, IT sector, Fall 2024
# Montreal
# Apply link: Apply on employer site
# Size
# 10000+ Employees
# Founded
# 1900
# Type
# Company - Private
# Industry
# Banking & Lending
# Sector
# Finance
# Revenue
# Unknown / Non-Applicable
# Apply on employer site found
# An unexpected error occurred: Message:
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7EC48B5D2+29090]
# 	(No symbol) [0x00007FF7EC3FE689]
# 	(No symbol) [0x00007FF7EC2BB1CA]
# 	(No symbol) [0x00007FF7EC30EFD7]
# 	(No symbol) [0x00007FF7EC30F22C]
# 	(No symbol) [0x00007FF7EC3597F7]
# 	(No symbol) [0x00007FF7EC33672F]
# 	(No symbol) [0x00007FF7EC3565D9]
# 	(No symbol) [0x00007FF7EC336493]
# 	(No symbol) [0x00007FF7EC3009B1]
# 	(No symbol) [0x00007FF7EC301B11]
# 	GetHandleVerifier [0x00007FF7EC7A8C5D+3295277]
# 	GetHandleVerifier [0x00007FF7EC7F4843+3605523]
# 	GetHandleVerifier [0x00007FF7EC7EA707+3564247]
# 	GetHandleVerifier [0x00007FF7EC546EB6+797318]
# 	(No symbol) [0x00007FF7EC40980F]
# 	(No symbol) [0x00007FF7EC4053F4]
# 	(No symbol) [0x00007FF7EC405580]
# 	(No symbol) [0x00007FF7EC3F4A1F]
# 	BaseThreadInitThunk [0x00007FFE014D257D+29]
# 	RtlUserThreadStart [0x00007FFE027AAF28+40]
#
# {'title': 'Internship, IT sector, Fall 2024', 'company': 'Desjardins', 'location': 'Montreal', 'apply_link': 'https://desjardins.wd10.myworkdayjobs.com/en-US/Desjardins/job/Montral/Stage--Secteur-TI--Automne-2024_R2406447-1', 'description': 'Desjardins\n4.0\nInternship, IT sector, Fall 2024\nMontreal\nApply on employer site\nApply on employer site\nAre you looking for a one-of-kind experience with an outstanding team in a modern environment? We\'re looking for bright interns who like to learn because with our squads, there\'s always something new. Start your career at Quebec\'s largest private IT employer—over 7,000 employees—it\'s a great opportunity! As a top employer that\'s committed to the next generation of IT professionals, There are several internship opportunities available.\nMore specifically, you will be required to :\nScrum master intern\nSupport your team in their appraisal and planning, while making sure that any roadblocks to delivering value are eliminated or avoided\nProject management intern\nSupport all aspects of project delivery up to final closure, and make sure deliverables are approved\nETL intern\nDesign, develop, automate and support complex applications to extract, transform and load data\nBusiness intelligence intern\nDesign, create and set up reports, dashboards and performance indicators to support strategic decision-making\nOperations systems analysis intern\nImplement infrastructure based on architecture specifications and operational standards\nDevelopment intern\nActively participate in developing the execution strategy, analysis and design, coding, testing and documentation of programs and/or applications\nData engineering intern\nHelp collect, integrate, consolidate, clean, store and mine data flows\nHelp develop, maintain, support and run computer applications and data pipelines, while ensuring the functional analysis, IT design, coding, fine-tuning and documentation\nBusiness administration intern\nAnalyze issues related to your field\nConduct research and preliminary analysis\nDevelop initial outlines of tools and processes\nDraw on your comprehensive knowledge of the line of business\nAssist clients and partners\nIT Governance and compliance intern\nHelp develop IT governance and compliance approaches\nDocument several internal processes and procedures related to risk and compliance practices\nEnsure the quality of evidence related to general IT controls and follow up with compliance officers\nEnsure certain files are handled\nQuality assurance intern\nActively participate in quality assurance tests, identify test scenarios (unit, functional, system, non-regression), implement the environment, carry out scenarios and communicate results\nWhat you bring to the table\nYour educational institution must credit or certify your internship toward an ACS, a DCS, a bachelor\'s degree or a master\'s degree in an appropriate discipline\nRelevant work/internship experience\nKnowledge of French is required\nAt Desjardins, we don\'t just support youth. We value their talent. There\'s a difference\n#LI-Hybrid\nAt Desjardins, we believe in equity, diversity and inclusion. We\'re committed to welcoming, respecting and valuing people for who they are as individuals, learning from their differences, embracing their uniqueness, and providing a positive workplace for all. At Desjardins, we have zero tolerance for discrimination of any kind. We believe our teams should reflect the diversity of the members, clients and communities we serve.\nIf there\'s something we can do to help make the recruitment process or the job you\'re applying for more accessible, let us know. We can provide accommodations at any stage in the recruitment process. Just ask!\nJob Family\nInformation technology (FG)\nShow less\nCompany overview\nSize\n10000+ Employees\nFounded\n1900\nType\nCompany - Private\nIndustry\nBanking & Lending\nSector\nFinance\nRevenue\nUnknown / Non-Applicable\nDesjardins Ratings\n4.0\n82 %\nRecommend to a fri ...
# no alert buton found or unable to click it, safely pass
# Ericsson
# GEN AI Solution Architect - Intern
# Montreal
# Apply link: Apply on employer site
# Size
# 10000+ Employees
# Founded
# 1876
# Type
# Company - Public
# Industry
# Telecommunications Services
# Sector
# Telecommunications
# Revenue
# $10+ billion (USD)
# Apply on employer site found
# An unexpected error occurred: Message:
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7EC48B5D2+29090]
# 	(No symbol) [0x00007FF7EC3FE689]
# 	(No symbol) [0x00007FF7EC2BB1CA]
# 	(No symbol) [0x00007FF7EC30EFD7]
# 	(No symbol) [0x00007FF7EC30F22C]
# 	(No symbol) [0x00007FF7EC3597F7]
# 	(No symbol) [0x00007FF7EC33672F]
# 	(No symbol) [0x00007FF7EC3565D9]
# 	(No symbol) [0x00007FF7EC336493]
# 	(No symbol) [0x00007FF7EC3009B1]
# 	(No symbol) [0x00007FF7EC301B11]
# 	GetHandleVerifier [0x00007FF7EC7A8C5D+3295277]
# 	GetHandleVerifier [0x00007FF7EC7F4843+3605523]
# 	GetHandleVerifier [0x00007FF7EC7EA707+3564247]
# 	GetHandleVerifier [0x00007FF7EC546EB6+797318]
# 	(No symbol) [0x00007FF7EC40980F]
# 	(No symbol) [0x00007FF7EC4053F4]
# 	(No symbol) [0x00007FF7EC405580]
# 	(No symbol) [0x00007FF7EC3F4A1F]
# 	BaseThreadInitThunk [0x00007FFE014D257D+29]
# 	RtlUserThreadStart [0x00007FFE027AAF28+40]
#
# {'title': 'GEN AI Solution Architect - Intern', 'company': 'Ericsson', 'location': 'Montreal', 'apply_link': 'https://jobs.ericsson.com/careers/job/563121760623452?domain=ericsson.com', 'description': 'Ericsson\n4.0\nGEN AI Solution Architect - Intern\nMontreal\nApply on employer site\nApply on employer site\nJoin our Team\nArchitecte de solutions GEN AI - Stagiaire\n\nLieu : Montréal, Québec. Hybride, selon la demande de l\'équipe.\nDurée : Min 8 mois.\nDate de début : 6 janvier 2025\nVeuillez télécharger votre relevé de notes lorsque vous postulez. (Utilisez l\'onglet de téléchargement « Lettre de motivation »)\n\nÀ propos de cette opportunité\nCloud Solution Architect, un rôle essentiel qui pilote nos études techniques et solutions Cloud de bout en bout en fonction de l\'évolution de la technologie Cloud, des exigences des parties prenantes et des besoins métiers.\n\nCe que vous ferez\nCréez et maintenez une architecture de haut niveau.\nSoutenir le développement et l\'évolution des capacités de l\'environnement Cloud & Application (C&A) afin qu\'elles adhèrent à l\'architecture de haut niveau.\nGouvernance des activités de C&A Environment pour assurer l\'alignement avec l\'architecture de haut niveau.\nSoutenir la gouvernance des architectures de niveau inférieur, le développement et l\'évolution.\nSoutenir l\'environnement C&A dans l\'alignement des outils, des services et des capacités.\nÉtablissement et mise à jour de descriptions architecturales (artefacts) dans différentes vues telles que la technologie, l\'application et l\'information\nEffectuer des revues architecturales de différents domaines d\'intérêt.\nEngagez-vous dans des discussions détaillées avec les parties prenantes sur leur stratégie technologique et les principaux goulets d\'étranglement\n\nVous apporterez\nÉtudiants actuels en master et doctorat\nLivraison de solutions cloud.\nArchitecture, environnement virtuel, technologie, protocole et interface.\nGamme de produits Ericsson.\n\nLocation: Montreal, Quebec. Hybrid, as per requested by the team.\nDuration: Min 8 months.\nStart date: Jan 6th, 2025\n\nPlease upload your transcript when applying. (Use the "Cover letter" uploading tab)\n\nAbout this opportunity\nCloud Solution Architect, a critical role that drives our Cloud end-to-end technical studies and solutions based on Cloud Technology evolution, and stakeholders requirements and business needs.\n\nWhat you will do\nCreate and maintain high level architecture.\nSupport development and evolution of Cloud & Application (C&A) Environment capabilities so that they adhere to the high-level architecture.\nGovernance of C&A Environment activities to secure alignment with the high-level architecture.\nSupport governance of lower-level architectures, development and evolution.\nSupport C&A Environment in alignment of tools, services and capabilities.\nEstablishment and maintenance of architectural descriptions (artifacts) in different views such as technology, application, and information views\nPerform architectural reviews of different focus areas.\nEngage in detailed study analysis discussions with stakeholders about their technology strategy and key bottlenecks.\n\nYou will bring\nCurrent Master and PhD students\nCloud Solution Delivery.\nArchitecture, Virtual Environment, Technology, Protocol and Interface.\nEricsson Product Portfolio.\n\nThis position reports to Head of C&A Technology and Portfolio.\n\nWhy join Ericsson?\nAt Ericsson, you´ll have an outstanding opportunity. The chance to use your skills and imagination to push the boundaries of what´s possible. To build solutions never seen before to some of the world’s toughest problems. You´ll be challenged, but you won’t be alone. You´ll be joining a team of diverse innovators, all driven to go beyond the status quo to craft what comes next.\n\nWhat happens once you apply?\nClick Here to find all you need to know about what our typical hiring process looks like.\n\nEncouraging a diverse and inclusi ...
# no alert buton found or unable to click it, safely pass
# Shoppers Drug Mart / Pharmaprix
# Loyalty & Consumer Insights Analyst, Co-Op Student
# Toronto
# Apply link: Apply on employer site
# Size
# 1001 to 5000 Employees
# Founded
# 1962
# Type
# Subsidiary or Business Segment
# Industry
# Drug & Health Stores
# Sector
# Retail and wholesale
# Revenue
# $10+ billion (USD)
# Apply on employer site found
# An unexpected error occurred: Message:
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7EC48B5D2+29090]
# 	(No symbol) [0x00007FF7EC3FE689]
# 	(No symbol) [0x00007FF7EC2BB1CA]
# 	(No symbol) [0x00007FF7EC30EFD7]
# 	(No symbol) [0x00007FF7EC30F22C]
# 	(No symbol) [0x00007FF7EC3597F7]
# 	(No symbol) [0x00007FF7EC33672F]
# 	(No symbol) [0x00007FF7EC3565D9]
# 	(No symbol) [0x00007FF7EC336493]
# 	(No symbol) [0x00007FF7EC3009B1]
# 	(No symbol) [0x00007FF7EC301B11]
# 	GetHandleVerifier [0x00007FF7EC7A8C5D+3295277]
# 	GetHandleVerifier [0x00007FF7EC7F4843+3605523]
# 	GetHandleVerifier [0x00007FF7EC7EA707+3564247]
# 	GetHandleVerifier [0x00007FF7EC546EB6+797318]
# 	(No symbol) [0x00007FF7EC40980F]
# 	(No symbol) [0x00007FF7EC4053F4]
# 	(No symbol) [0x00007FF7EC405580]
# 	(No symbol) [0x00007FF7EC3F4A1F]
# 	BaseThreadInitThunk [0x00007FFE014D257D+29]
# 	RtlUserThreadStart [0x00007FFE027AAF28+40]
#
# {'title': 'Loyalty & Consumer Insights Analyst, Co-Op Student', 'company': 'Shoppers Drug Mart / Pharmaprix', 'location': 'Toronto', 'apply_link': 'https://myview.wd3.myworkdayjobs.com/loblaw_careers/job/243-Consumers-Road-Toronto-ON/Loyalty---Consumer-Insights-Analyst--Co-Op-Student_R2000494093?source=indeed&utm_source=indeed.com&utm_medium=referral', 'description': 'Shoppers Drug Mart / Pharmaprix\n3.5\nLoyalty & Consumer Insights Analyst, Co-Op Student\nToronto\nApply on employer site\nApply on employer site\nReferred applicants should not apply directly to this role.\nAll referred applicants must first be submitted through Workday by a current Loblaw Colleague.\nCome make your difference in communities across Canada, where authenticity, trust and making connections is valued – as we shape the future of Canadian retail, together. Our unique position as one of the country’s largest employers, coupled with our commitment to positively impact the lives of all Canadians, provides our colleagues a range of opportunities and experiences to help Canadians Live Life Well®.\n\nAt Loblaw Companies Limited, we succeed through collaboration and commitment and set a high bar for ourselves and those around us. Whether you are just starting your career, re-entering the workforce, or looking for a new job, this is where you belong.\nTerm Length: 4 months\nTerm Start: January 8, 2025\nTerm End: April 18, 2025\nReturn to Office: As of October 15, 2024 Loblaw has adopted the following Hybrid working model (a combination of working between the office and remotely). Colleagues will continue working remotely up to 1 day a week, while spending the other 4 days in the office.\nThe decision to join a company is a big one. We have opportunities for hard working, energetic and reliable people just like you!\nWe are hiring a Analyst, Loyalty & Consumer Insights. Reporting to the Senior Manager Loyalty & Consumer Insights, the Analyst will be responsible for providing objective, value-added analysis and recommendations to facilitate discussions & decisions related to high profile initiatives at Shoppers Drug Mart and Joe Fresh.\nWhat You’ll Do:\nSupport the execution of loyalty campaigns at Shoppers Drug Mart and Joe Fresh\nSupport the development of loyalty offer strategy. Optimize loyalty investment to maximize incremental sales and profit\nDeliver weekly reporting on loyalty campaign performance, and operational KPIs\nSupport marketing and digital teams on ad-hoc analysis and leverage customer data to deliver meaningful insights to drive business strategy\nSynthesize large amounts of data from multiple sources, including customer transaction data, consumer & syndicated research, market share, and campaign results. Extrapolate and interpret appropriate information to deliver value add recommendations\nWhat You’ll Need:\nUniversity degree in Business, Economics, Mathematics, Engineering, or Computer Science\nProfessional or co-op experience is an asset. Ideally in Retail, CPG industry, Consumer Finance, or Telecommunications\nAbility to synthesize large amount of data into insights\nStrong interpersonal skills and comfortable collaborating within cross functional team\nDemonstrated strong business acumen\nAdvanced knowledge of MS Excel\nBasic knowledge of MS Access, SQL, Python is an asset\nOur commitment to Sustainability and Social Impact is an essential part of the way we do business, and we focus our attention on areas where we can have the greatest impact. Our approach to sustainability and social impact is based on three pillars – Environment, Sourcing and Community – and we are constantly looking for ways to demonstrate leadership in these important areas. Our CORE Values – Care, Ownership, Respect and Excellence – guide all our decision-making and come to life through our Blue Culture. We offer our colleagues progressive careers, comprehensive training, flexibility, and other competitive benefits – these are some of the many reasons why we are ...
# no alert buton found or unable to click it, safely pass

# %%
from bs4 import BeautifulSoup
# read html from file
with open("glassdoor_jobs.html", "r") as file:
    html = file.read()
#parse html with beautiful soup
soup = BeautifulSoup(html, "html.parser")
#find all job cards with class JobCard_jobCardContainer__arQlW
job_cards = soup.find_all("div", class_="JobCard_jobCardContainer__arQlW")
job_cards_count = len(job_cards)
subset = job_cards[:5]
print(f"Number of job cards: {job_cards_count}")
# Out:
# Number of job cards: 900

# %%
from bs4 import BeautifulSoup
from datetime import datetime
import json

def extract_jobs_from_html(html_file):
    # Read HTML file
    with open(html_file, 'r', encoding='utf-8') as file:
        html_content = file.read()

    # Parse HTML
    soup = BeautifulSoup(html_content, 'html.parser')
    
    # Find all job cards
    job_cards = soup.find_all('div', class_='JobCard_jobCardContainer__arQlW')
    
    # List to store job data
    jobs_data = []
    
    # Extract info from each job card
    for card in job_cards:
        job = {}
        
        # Extract job title
        title_elem = card.find('a', class_='JobCard_jobTitle__GLyJ1')
        job['title'] = title_elem.text.strip() if title_elem else None
        
        # Extract company name
        company_elem = card.find('span', class_='EmployerProfile_compactEmployerName__9MGcV')
        job['company'] = company_elem.text.strip() if company_elem else None
        
        # Extract location
        location_elem = card.find('div', class_='JobCard_location__Ds1fM')
        job['location'] = location_elem.text.strip() if location_elem else None
        
        # Extract salary if available
        salary_elem = card.find('div', class_='JobCard_salaryEstimate__QpbTW')
        job['salary'] = salary_elem.text.strip() if salary_elem else None
        
        # Extract posting date
        date_elem = card.find('div', class_='JobCard_listingAge__jJsuc')
        job['posting_date'] = date_elem.text.strip() if date_elem else None
        
        # Extract job link
        link_elem = card.find('a', class_='JobCard_trackingLink__HMyun')
        job['link'] = link_elem.get('href') if link_elem else None
        
        # Add timestamp
        job['extracted_at'] = datetime.now().isoformat()
        
        jobs_data.append(job)
    
    return jobs_data

def save_jobs_to_json_file(jobs_data, output_file):
    with open(output_file, 'w', encoding='utf-8') as f:
        json.dump(jobs_data, f, indent=2, ensure_ascii=False)

if __name__ == "__main__":
    # File paths
    html_file = "./glassdoor_jobs.html"
    output_file = "./glassdoor_jobs.json"
    
    # Extract jobs data
    jobs = extract_jobs_from_html(html_file)
    
    # Print summary
    print(f"Extracted {len(jobs)} jobs")
    
    # Save to JSON file
    save_jobs_to_json_file(jobs, output_file)
    print(f"Jobs data saved to {output_file}")
# Out:
# Extracted 900 jobs
# Jobs data saved to ./glassdoor_jobs.json

# %%
subset = job_cards[:5]
# Out:
# [<div class="JobCard_jobCardContainer__arQlW"><div class="jobCard JobCard_jobCardContent__JQ5Rq JobCardWrapper_easyApplyLabelNoWrap__PtpgT"><div><div class="EmployerProfile_profileContainer__63w3R EmployerProfile_compact__28h9t" id="job-employer-1009543546160" target="_blank"><div aria-label="" class="avatar_AvatarContainer__040QC avatar-base_AvatarContainer__Arxub" data-display-variant="square" data-size="xs" data-type="image" image="https://media.glassdoor.com/sql/8605843/dataannotation-squareLogo-1714066456196.png" imagealttext="DataAnnotation Logo" imageloading="lazy"><div class="avatar-base_ImageContentWrapper__2rZhY"><img alt="DataAnnotation Logo" class="avatar-base_Image__2RcF9" loading="lazy" src="https://media.glassdoor.com/sql/8605843/dataannotation-squareLogo-1714066456196.png"/></div></div><div class="EmployerProfile_employerInfo___kmLv EmployerProfile_employerWithLogo__xgrWU"><div class="EmployerProfile_employerNameContainer__ptolz"><span class="EmployerProfile_compactEmployerName__9MGcV">DataAnnotation</span><div aria-hidden="false" aria-live="polite" aria-valuenow="2.9" class="rating-single-star_RatingSingleStarContainer__PEAtE" data-color-variant="secondary" data-size-variant="xs" role="meter"><span class="rating-single-star_RatingText__XENmU">2.9</span><svg aria-hidden="false" aria-live="polite" class="rating-single-star_RatingStar__akaYI" fill="none" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="m12 1 2.597 8.403H23l-6.798 5.194L18.798 23 12 17.806 5.202 23l2.596-8.403L1 9.403h8.403L12 1Z" fill="currentColor" stroke="currentColor"></path></svg></div></div></div></div><a class="JobCard_jobTitle__GLyJ1" data-test="job-title" href="https://www.glassdoor.ca/job-listing/graduate-research-intern-mathematics-ai-trainer-dataannotation-JV_IC2282814_KO0,47_KE48,62.htm?jl=1009543546160" id="job-title-1009543546160" tabindex="-1">Graduate Research Intern, Mathematics - AI Trainer</a><div class="JobCard_location__Ds1fM" data-test="emp-location" id="job-location-1009543546160">Guelph</div><div class="JobCard_salaryEstimate__QpbTW" data-test="detailSalary" id="job-salary-1009543546160">$57.11<!-- --> <!-- -->Per hour<!-- --> <span class="JobCard_salaryEstimateType__jDbdd">(Employer Est.)</span></div><a aria-labelledby="job-title-1009543546160 job-salary-1009543546160 job-location-1009543546160 job-employer-1009543546160" class="JobCard_trackingLink__HMyun" data-test="job-link" href="/partner/jobListing.htm?pos=101&amp;ao=1110586&amp;s=58&amp;guid=000001949f6e26dfb6bea4c0bafb6d9d&amp;src=GD_JOB_AD&amp;t=SR&amp;vt=w&amp;uido=4FD64BD4688D754C9A88D3475797ACA8&amp;cs=1_17bd5075&amp;cb=1737841584334&amp;jobListingId=1009543546160&amp;cpc=3E3A0B328A81795B&amp;jrtk=5-yul1-0-1iifms9p2gc39800-d2e76e0dd134c6de---6NYlbfkN0CnM4TERr6XuVBW3VTRACvDXDx9S3Pbn6a0SwhkmoLTiByC3ECiiXeNjK6o96Z9l0G6c1d7QrgH-VsfI5O0-LUA3RnJTU6DB7qFcTn7uprhLx9ZIYveEIU7H6FSO4V2PvgotEHK5qP0HsyQ3xMFKCtgNrS9E9QvIPXe-oEpUCMQQPfEpCWjzdIlM4ppdQnp05Th91PsLPh0GzGl84TezmKxP9qBzzstYs3gESAWzX6_rJ_xo5p5Nj91Ep0Bqr2-2ZLctIyQ1q8STSoumZI43JxhAordYYQUg-gemJYtlfAV1ufdQ2pOoENw-VlzX6ZA5zb_TmS4Sx5lYGS1wrykGK-mjL8gJLiEUC5NheS8ddomHxNr2tB5TXxNwjGwDc7mp9X_vFqomG4L-heRw1LHjHgIEznEdXejTTMtal2zdV6AObhejnDKliIisFsDnY-_7zUmT-rQsZf0Gffw9Y_L_Ntw6fGgPBH26Hhn4cVMgBkfVd2eD655Qd02Do29OvwHyd3rSnj6r-p33YB43Xkd4dtHj6WEttozgzqKpR_RguhIvv6Ay_bHFo17LLvIt3PKponS8w48ssSpjq7dyBH5uzxAneivUX7qQc74Rk9hi2dAOCFT0cJARWVoob1uUMx3nRld_6Tzl5nW7cwz-mvJRdvwfCVOVYJwcim448tTP9bHFc5mv-a67OKYbchThSFIcnx98qTU8DjBV7qv_E7oYQnfcHVGi7YD2qJqgn9MSnMMfmem_XCHsSg8QBScAw0QsN3TQr01F-VlXXKhXHMS6by6sAPHZNS-SkNiYm1ih_2aqnewMWLFPe1Fro63Ec8bwiIDmuDbHaNi1xlHoRKAdyBmEq3VFuClqGLKoJtgNXXRxvwt5oLkvkieISOs3t-8bi8mEdW7QHEkS6PgaYpHa9E55WtCAYdvZSjyZbFJ5JIuHXQNx0r05_md6HKFSrnS__VEvqCdSSnfqTb6e3oIeUlMpmOHdYp-X6A%3D" rel="nofollow" target="_blank"></a></div><div class="JobCard_listingAge__jJsuc" data-test="job-age">30d+</div></div><div class="JobCard_saveButtonContainer__IoxGI"><button aria-label="Save" class="B ...
#  <div class="JobCard_jobCardContainer__arQlW"><div class="jobCard JobCard_jobCardContent__JQ5Rq JobCardWrapper_easyApplyLabelNoWrap__PtpgT"><div><div class="EmployerProfile_profileContainer__63w3R EmployerProfile_compact__28h9t" id="job-employer-1009480623792" target="_blank"><div aria-label="" class="avatar_AvatarContainer__040QC avatar-base_AvatarContainer__Arxub" data-display-variant="square" data-size="xs" data-type="image" image="https://media.glassdoor.com/sql/8605843/dataannotation-squareLogo-1714066456196.png" imagealttext="DataAnnotation Logo" imageloading="lazy"><div class="avatar-base_ImageContentWrapper__2rZhY"><img alt="DataAnnotation Logo" class="avatar-base_Image__2RcF9" loading="lazy" src="https://media.glassdoor.com/sql/8605843/dataannotation-squareLogo-1714066456196.png"/></div></div><div class="EmployerProfile_employerInfo___kmLv EmployerProfile_employerWithLogo__xgrWU"><div class="EmployerProfile_employerNameContainer__ptolz"><span class="EmployerProfile_compactEmployerName__9MGcV">DataAnnotation</span><div aria-hidden="false" aria-live="polite" aria-valuenow="2.9" class="rating-single-star_RatingSingleStarContainer__PEAtE" data-color-variant="secondary" data-size-variant="xs" role="meter"><span class="rating-single-star_RatingText__XENmU">2.9</span><svg aria-hidden="false" aria-live="polite" class="rating-single-star_RatingStar__akaYI" fill="none" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="m12 1 2.597 8.403H23l-6.798 5.194L18.798 23 12 17.806 5.202 23l2.596-8.403L1 9.403h8.403L12 1Z" fill="currentColor" stroke="currentColor"></path></svg></div></div></div></div><a class="JobCard_jobTitle__GLyJ1" data-test="job-title" href="https://www.glassdoor.ca/job-listing/graduate-research-intern-biology-ai-trainer-dataannotation-JV_KO0,43_KE44,58.htm?jl=1009480623792" id="job-title-1009480623792" tabindex="-1">Graduate Research Intern, Biology - AI Trainer</a><div class="JobCard_location__Ds1fM" data-test="emp-location" id="job-location-1009480623792">Remote</div><div class="JobCard_salaryEstimate__QpbTW" data-test="detailSalary" id="job-salary-1009480623792">$57.11<!-- --> <!-- -->Per hour<!-- --> <span class="JobCard_salaryEstimateType__jDbdd">(Employer Est.)</span></div><a aria-labelledby="job-title-1009480623792 job-salary-1009480623792 job-location-1009480623792 job-employer-1009480623792" class="JobCard_trackingLink__HMyun" data-test="job-link" href="/partner/jobListing.htm?pos=102&amp;ao=1110586&amp;s=58&amp;guid=000001949f6e26dfb6bea4c0bafb6d9d&amp;src=GD_JOB_AD&amp;t=SR&amp;vt=w&amp;uido=4FD64BD4688D754C9A88D3475797ACA8&amp;cs=1_46b652da&amp;cb=1737841584335&amp;jobListingId=1009480623792&amp;cpc=F8C81BAEBBCECB62&amp;jrtk=5-yul1-0-1iifms9p2gc39800-02b53f29f031d300---6NYlbfkN0CnM4TERr6XuVBW3VTRACvDXDx9S3Pbn6a0SwhkmoLTiP0a4lYCvtF3Xm0gK9wJPbvZxLGTYYyx2zVm0jdukbOwpHXPHPzfPgsUFChNUTtN2q5gCBJwaouPkAUPEQplsDJ2KR_E7xWyAldENPd7Ltj1Ugl_48np-BWmH6V6ukd576BZ9tDoE6-al1ESEomEvlm5mx2VQGoCkD-ChPvqkJsQ-nzqjiiVSz3h9KWWSjjCr66t70_a1hvbxXgc0hlig_BmOFI0sT0fDgRDUpoJxO70Oe8V1ljfHbf-KIIp0ePUVry4RzjFZq6NxMOvPdRyNWRQwbyM-WJFl2vcbDpfoa1MJpd1aGFSnR2bLZ2eIuCxCru58kn41eBsVdbh1S1TDpFWcJQujDjXe3YNa-1jdUePV-DoAZuLn18nSzVVNIuP05aCQgcxuTqCdDhKQga2kkuedkMxyAYlTo0yC_5p6qNCsc79dn1tMnTqZlt640qpCOptypm-MABDXCd2z8tWiuJQLOra1usfvYyev8l8pGmajOwhVPJzbOZq5lt4nJUeSfB6IxOsRSe-ZfUrbC8sHlcLlSYua2whudg4qOppeVwqfOJZW31aBz_3cow1mC4mC62MaQinQ6oq75NaA0e56SO5LfTrOvrfJmiHNhECdAGhsgPP_wXwRHXQBOJhDanDgFVFtPV7IWyizukGZtqwXRj0zhB6DQdKWoQ0iZHBvZw7oCTTYADNC7dgnpGKdO_bQS7d7BapjamtAkXl5OBSA-ODV3WthzsJ4hYniqd3ZuHj-fG9iB11o-Stb932eb8skcXem2N1idnqM2f8OY-biqHywpYHM0MS4t08Gvt8Fodt2PmxJdpo08hYF03W-ZxUumwJSNvEEJmaMd3rk5zWMN2yjcQMbsAgEDnQPdmrGB-xtrRgzvZwlE-Vxi_p5M7-U4ZRAZ6-ccLoXgjhUrnQrbdHtlMpJVfzaNWWjgb83npy" rel="nofollow" target="_blank"></a></div><div class="JobCard_listingAge__jJsuc" data-test="job-age">30d+</div></div><div class="JobCard_saveButtonContainer__IoxGI"><button aria-label="Save" class="BookmarkButton_buttonWrapper__Rdc ...
#  <div class="JobCard_jobCardContainer__arQlW"><div class="jobCard JobCard_jobCardContent__JQ5Rq JobCardWrapper_easyApplyLabelNoWrap__PtpgT"><div><div class="EmployerProfile_profileContainer__63w3R EmployerProfile_compact__28h9t" id="job-employer-1009543735073" target="_blank"><div aria-label="" class="avatar_AvatarContainer__040QC avatar-base_AvatarContainer__Arxub" data-display-variant="square" data-size="xs" data-type="image" image="https://media.glassdoor.com/sql/8605843/dataannotation-squareLogo-1714066456196.png" imagealttext="DataAnnotation Logo" imageloading="lazy"><div class="avatar-base_ImageContentWrapper__2rZhY"><img alt="DataAnnotation Logo" class="avatar-base_Image__2RcF9" loading="lazy" src="https://media.glassdoor.com/sql/8605843/dataannotation-squareLogo-1714066456196.png"/></div></div><div class="EmployerProfile_employerInfo___kmLv EmployerProfile_employerWithLogo__xgrWU"><div class="EmployerProfile_employerNameContainer__ptolz"><span class="EmployerProfile_compactEmployerName__9MGcV">DataAnnotation</span><div aria-hidden="false" aria-live="polite" aria-valuenow="2.9" class="rating-single-star_RatingSingleStarContainer__PEAtE" data-color-variant="secondary" data-size-variant="xs" role="meter"><span class="rating-single-star_RatingText__XENmU">2.9</span><svg aria-hidden="false" aria-live="polite" class="rating-single-star_RatingStar__akaYI" fill="none" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="m12 1 2.597 8.403H23l-6.798 5.194L18.798 23 12 17.806 5.202 23l2.596-8.403L1 9.403h8.403L12 1Z" fill="currentColor" stroke="currentColor"></path></svg></div></div></div></div><a class="JobCard_jobTitle__GLyJ1" data-test="job-title" href="https://www.glassdoor.ca/job-listing/graduate-research-intern-physics-ai-trainer-dataannotation-JV_KO0,43_KE44,58.htm?jl=1009543735073" id="job-title-1009543735073" tabindex="-1">Graduate Research Intern, Physics - AI Trainer</a><div class="JobCard_location__Ds1fM" data-test="emp-location" id="job-location-1009543735073">Quebec</div><div class="JobCard_salaryEstimate__QpbTW" data-test="detailSalary" id="job-salary-1009543735073">$57.11<!-- --> <!-- -->Per hour<!-- --> <span class="JobCard_salaryEstimateType__jDbdd">(Employer Est.)</span></div><a aria-labelledby="job-title-1009543735073 job-salary-1009543735073 job-location-1009543735073 job-employer-1009543735073" class="JobCard_trackingLink__HMyun" data-test="job-link" href="/partner/jobListing.htm?pos=103&amp;ao=1110586&amp;s=58&amp;guid=000001949f6e26dfb6bea4c0bafb6d9d&amp;src=GD_JOB_AD&amp;t=SR&amp;vt=w&amp;uido=4FD64BD4688D754C9A88D3475797ACA8&amp;cs=1_74b3d9b5&amp;cb=1737841584335&amp;jobListingId=1009543735073&amp;cpc=EFEC3C86B5366A8C&amp;jrtk=5-yul1-0-1iifms9p2gc39800-fcd7859f2d2ddc90---6NYlbfkN0CnM4TERr6XuVBW3VTRACvDXDx9S3Pbn6a0SwhkmoLTiP0a4lYCvtF3sGYLWdFCLBEno6MnkO3Jkv_SNDNmlPdkjRA9na6pqjehhXfeKOMeLS0-K3OQNBq0-iUlBDaFNkPXsBGnNGJfd8XT_E02W24jTKLolgafKA-2p33UR1J35qWW6DdqxALYMDmoKmVsyjxSL50PD9Ti3p8nAXXOKR7kCnRcwv16xbpkCFNYUzIQivVFxcrui5LhtYGkGS3hNlRopSArbNE4ccAApOKDZE_IHfEIIJec_GuDqx5S8EHSRiM5TjOBnL6DHrZaESX4ak0cBJiOOULHcFmdu-HIIKtF97yauEcHENuRzULiUHjpPvtXGDPjLUd0UASh32sl9o19hMDimXw67tDAjbsLC_wmV7DWwIepATdpgzoYcfDuTEvHo6ePYSVa9uzuejHPw95VYBZdkcknHCOS7ZuBhAyVDGyBQUHXsZ4ApcKGwrImnUTDIvrlHf6oEefLpMhuIS-ZYsk-6LS2WzOMRVioqXWhdrlpijt7P7KWaopfxkCsJgwq-ZdGPCBpWH4TutSlDVWQZjtqypshyRx-ivrrrYzuB2OYUnLgJHzX12WwU2kACk4_7hNm0SX-RVm-7HRWXrm6JxPSE-e5lDD0cOQ80Z-ORrK7M_V65BgGovZi-t8bv68OAv6giHAFVVd_rHUPLSVcoy9AlV0xC4SOuPBQUYytEMb7d4H1vltCcSVpDI3WCPcezFiHfZ1Akv4SESgzhlfEQ6X3nxtN6rdlGe9sGnFQSJoCoylnxismYlE2KJFtwhKHgiNlc_Htz3e0SFmWoE0AhEH5j_n3IpgzlbVvEocpmZSM0PPcnl6aq5JLsZ2JbWL2uPmuZoAvAv-AxfuH9ZKuLEu6GN1JKyPFZ6zPoFc_v1IRrHCCGEceiVzQwO8Hb54bWI6mSgcOua2OC-ZZ7l_Cya5S9dI_ikO8ALLGx7ZlOrVbhsbA2PG-xUOGopY8xQ%3D%3D" rel="nofollow" target="_blank"></a></div><div class="JobCard_listingAge__jJsuc" data-test="job-age">30d+</div></div><div class="JobCard_saveButtonContainer__IoxGI"><button aria-label="Save" class="Bookm ...
#  <div class="JobCard_jobCardContainer__arQlW"><div class="jobCard JobCard_jobCardContent__JQ5Rq JobCardWrapper_easyApplyLabelNoWrap__PtpgT"><div><div class="EmployerProfile_profileContainer__63w3R EmployerProfile_compact__28h9t" id="job-employer-1009457696914" target="_blank"><div aria-label="" class="avatar_AvatarContainer__040QC avatar-base_AvatarContainer__Arxub" data-display-variant="square" data-size="xs" data-type="image" image="https://media.glassdoor.com/sql/683893/vale-squareLogo-1711129242194.png" imagealttext="Vale Logo" imageloading="lazy"><div class="avatar-base_ImageContentWrapper__2rZhY"><img alt="Vale Logo" class="avatar-base_Image__2RcF9" loading="lazy" src="https://media.glassdoor.com/sql/683893/vale-squareLogo-1711129242194.png"/></div></div><div class="EmployerProfile_employerInfo___kmLv EmployerProfile_employerWithLogo__xgrWU"><div class="EmployerProfile_employerNameContainer__ptolz"><span class="EmployerProfile_compactEmployerName__9MGcV">Vale</span><div aria-hidden="false" aria-live="polite" aria-valuenow="4.3" class="rating-single-star_RatingSingleStarContainer__PEAtE" data-color-variant="secondary" data-size-variant="xs" role="meter"><span class="rating-single-star_RatingText__XENmU">4.3</span><svg aria-hidden="false" aria-live="polite" class="rating-single-star_RatingStar__akaYI" fill="none" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="m12 1 2.597 8.403H23l-6.798 5.194L18.798 23 12 17.806 5.202 23l2.596-8.403L1 9.403h8.403L12 1Z" fill="currentColor" stroke="currentColor"></path></svg></div></div></div></div><a class="JobCard_jobTitle__GLyJ1" data-test="job-title" href="https://www.glassdoor.ca/job-listing/occupational-health-masters-co-op-student-vale-JV_IC4034875_KO0,41_KE42,46.htm?jl=1009457696914" id="job-title-1009457696914" tabindex="-1">Occupational Health, Masters Co-op Student</a><div class="JobCard_location__Ds1fM" data-test="emp-location" id="job-location-1009457696914">Greater Sudbury</div><div class="JobCard_salaryEstimate__QpbTW" data-test="detailSalary" id="job-salary-1009457696914">$82K - $107K<!-- --> <span class="JobCard_salaryEstimateType__jDbdd">(Glassdoor Est.)</span></div><a aria-labelledby="job-title-1009457696914 job-salary-1009457696914 job-location-1009457696914 job-employer-1009457696914" class="JobCard_trackingLink__HMyun" data-test="job-link" href="/partner/jobListing.htm?pos=104&amp;ao=1110586&amp;s=58&amp;guid=000001949f6e26dfb6bea4c0bafb6d9d&amp;src=GD_JOB_AD&amp;t=SR&amp;vt=w&amp;uido=4FD64BD4688D754C9A88D3475797ACA8&amp;cs=1_e878036a&amp;cb=1737841584335&amp;jobListingId=1009457696914&amp;cpc=A47415DDCBEBC78E&amp;jrtk=5-yul1-0-1iifms9p2gc39800-07298d7f927aa9dd---6NYlbfkN0DQyIsrLPX77HmZ3BvK7D3JLq1QHxP3e8mz12KCI0527NwF2ZJKYonETi6Tkf28zYQGYvXhI2HjRONcBgdbeF-6_DAibKxE10XOFMDE9wfBei1zZr_hmKYHs8U3LjZSOqNI1saTkLm5tDURsUV9WLR4AZVtheFK4U5FEumRG2HFT4BhYfwxk_1gghECEbx4Zy5aF7NkJqqKROEZ8RlTEjY5JBzAsMYYGy1jnNSZlnKsPy4x5YFoVXGfJYNteZJidZoS90iG6hokbfT1WW_FIARTxjOkMOA4E1L0j0mQBtPCGDtsw3zTnTzZv2C6FpYpdic4LNOwyZlX6Lhi-jf--l6NTrtkgB1jJFtdjawNMtj9XWJrziVY3_GkaY71a4Yk_pXIyCQiZRm7YboE9KRQjermA-NDiR2Aym8-pD0KvzjfFmaRjM92BsgcnhZb_y-ciLO4ZohIqaRwWEHwBX4FsT6RC14gNde8k9o0zobrdFnnGVIjMR2ubUwGd-JgsbsFK8yn8zSaFdDwkqMrOdM4mCxsbtUX7j6otSf0QTETxE-fmiS_xMr2x3_xNLMXdtIrTxZSpyPBJGIHREnAv1FdAIAUcnguPOoZcHUF2fwrEx6O6dvMB0Rps780vH0F4pji8yxisyOqCL4RLMRsmYFd0IgSVXN9xDu2FaBbQ1M_M_yGBJAciZJF0bB9SnVQ12vOLJN1B6wNCHE6TST9nX3dBtjbH6kgIUbXMjXCEOcZxR8RV1bXerT8UxMr" rel="nofollow" target="_blank"></a></div><div class="JobCard_listingAge__jJsuc" data-test="job-age">30d+</div></div><div class="JobCard_saveButtonContainer__IoxGI"><button aria-label="Save" class="BookmarkButton_buttonWrapper__Rdck7 button-base_Button__knLaX" data-test="save-job" type="button"><div aria-describedby="job-title-1009457696914" class="BookmarkButton_svgWrapper__8np0X"><svg fill="none" height="24" width="24" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M19 21.315V3.591C19 2.72 18.306 2 ...
#  <div class="JobCard_jobCardContainer__arQlW"><div class="jobCard JobCard_jobCardContent__JQ5Rq JobCardWrapper_easyApplyLabelNoWrap__PtpgT"><div><div class="EmployerProfile_profileContainer__63w3R EmployerProfile_compact__28h9t" id="job-employer-1009543765528" target="_blank"><div aria-label="" class="avatar_AvatarContainer__040QC avatar-base_AvatarContainer__Arxub" data-display-variant="square" data-size="xs" data-type="image" image="https://media.glassdoor.com/sql/8605843/dataannotation-squareLogo-1714066456196.png" imagealttext="DataAnnotation Logo" imageloading="lazy"><div class="avatar-base_ImageContentWrapper__2rZhY"><img alt="DataAnnotation Logo" class="avatar-base_Image__2RcF9" loading="lazy" src="https://media.glassdoor.com/sql/8605843/dataannotation-squareLogo-1714066456196.png"/></div></div><div class="EmployerProfile_employerInfo___kmLv EmployerProfile_employerWithLogo__xgrWU"><div class="EmployerProfile_employerNameContainer__ptolz"><span class="EmployerProfile_compactEmployerName__9MGcV">DataAnnotation</span><div aria-hidden="false" aria-live="polite" aria-valuenow="2.9" class="rating-single-star_RatingSingleStarContainer__PEAtE" data-color-variant="secondary" data-size-variant="xs" role="meter"><span class="rating-single-star_RatingText__XENmU">2.9</span><svg aria-hidden="false" aria-live="polite" class="rating-single-star_RatingStar__akaYI" fill="none" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="m12 1 2.597 8.403H23l-6.798 5.194L18.798 23 12 17.806 5.202 23l2.596-8.403L1 9.403h8.403L12 1Z" fill="currentColor" stroke="currentColor"></path></svg></div></div></div></div><a class="JobCard_jobTitle__GLyJ1" data-test="job-title" href="https://www.glassdoor.ca/job-listing/graduate-research-intern-chemistry-ai-trainer-dataannotation-JV_IC2284969_KO0,45_KE46,60.htm?jl=1009543765528" id="job-title-1009543765528" tabindex="-1">Graduate Research Intern, Chemistry - AI Trainer</a><div class="JobCard_location__Ds1fM" data-test="emp-location" id="job-location-1009543765528">Burlington</div><div class="JobCard_salaryEstimate__QpbTW" data-test="detailSalary" id="job-salary-1009543765528">$57.11<!-- --> <!-- -->Per hour<!-- --> <span class="JobCard_salaryEstimateType__jDbdd">(Employer Est.)</span></div><a aria-labelledby="job-title-1009543765528 job-salary-1009543765528 job-location-1009543765528 job-employer-1009543765528" class="JobCard_trackingLink__HMyun" data-test="job-link" href="/partner/jobListing.htm?pos=105&amp;ao=1110586&amp;s=58&amp;guid=000001949f6e26dfb6bea4c0bafb6d9d&amp;src=GD_JOB_AD&amp;t=SR&amp;vt=w&amp;uido=4FD64BD4688D754C9A88D3475797ACA8&amp;cs=1_b15b0e02&amp;cb=1737841584335&amp;jobListingId=1009543765528&amp;cpc=C15A9BDEF637DEA8&amp;jrtk=5-yul1-0-1iifms9p2gc39800-fa5cc91961e085b2---6NYlbfkN0CnM4TERr6XuVBW3VTRACvDXDx9S3Pbn6a0SwhkmoLTiP0a4lYCvtF39o6E2hyMvNPanB7_EwnWEGqiWibXvXb9FdunSZC6Q2UULaxxMwjyji06wlcTl09wf2kxbXIzvyuXPrs5vfFf7Lu9C31Zx_KwSOq9QCamSdSaMaQJU9Xhx8NgCGgfBFyB6ZmzP3LTkhUMH_3BzxRyno00CMOWSAdlXADXNAy-6o15-u5iEeipc9ktBT-cqBxsMyxYxpoH7fZKMO36Jk1-ljI2NwGYjE7xeI1n5IHhRVqD1OB7N7dK79mPQD7tCu2ygocBW4DswhjUVS1NzDsiXDMTuo9XI7Sxq4dkHQywUQXiZbuDlA-0tT-kVuUpES5JgROfHyTcOtx6SfaLrk4m4Z9OuZSAd1-GkA2kFjf-4EAuUIax7-jaskP69SVauiIPaOP-NzdoZCI9d4wWmlHaunT9935ATmMqQ1JSpRIwnp_G3sfD7hEfKEkmebeSrwhMGLvtOCH23RZQ4pUgOVMvo7U8OBfKvbTIgKD0ip-UqW_VJ4hyjHmyl8xFBzQz1hSLVL-xXCy-3H3GKlUDoBFxVDYEDaIaulwOLimPTFnQGQaCvpDNnfuOpy4gw9Q7J_Fo-l3i-d1TxrrWrvAoEar9Wc0AJEeiu0o7RFE23vYZgPq1cTIozXr1Xxxz64o-C6S8bbEuSJPAjDd-TmWXlQhHonKTVt2TlqYZYV207DiuQgIf_fp5ftaOh5_GbPbcayF1zYlm3y4XcY56ntcVUqzXmyw9yZN4_S8tk9LqWtleAtLiq5trIhi-8jf5NaXhExRhW081hoL1kKRRI_0vgHHgEaSaLT0xGHM19bnI-hDNH-b-uUbNKEq-RO2q9pw7XTO6MGJvRvtcf71Ld_nr3KWvDO1BC-3aLYsTw9cBFKcz5SCNvQXwhueYB0O8w4nyF0agJEABhPfDVQKAw-d3W4it7oo3SuKUdw9U6RtvHVbC1sI%3D" rel="nofollow" target="_blank"></a></div><div class="JobCard_listingAge__jJsuc" data-test="job-age">30d+</div></div><div class="JobCard_saveButtonContainer__IoxGI"><button aria-label="Save" class="B ...

# %%
# Check latest timestamped documents in the collection
latest_jobs = collection.find().sort("timestamp", 1).limit(5)
latest_jobs_list = list(latest_jobs)
latest_jobs_count = len(latest_jobs_list)
print(f"Number of latest jobs: {latest_jobs_count}")
# Out:
# Number of latest jobs: 5

# %%
latest_jobs_list
# Out:
# [{'_id': ObjectId('6796ee38dcd2b6354236510b'),
#   'date-ingested-timestamp': '2025-01-26 21:23:52',
#   'status': 'OK'},
#  {'_id': ObjectId('66ddc2c0aef0eb3b303c2d19'),
#   'date-ingested-timestamp': '2024-09-08 11:29:04',
#   'status': 'OK'},
#  {'_id': ObjectId('66d9e11caef0eb3b303c2cc8'),
#   'date-ingested-timestamp': '2024-09-05 12:49:32',
#   'status': 'OK'},
#  {'_id': ObjectId('66d9e16baef0eb3b303c2cc9'),
#   'title': 'Software Engineer (Intern) Canada',
#   'company': 'Cisco Systems',
#   'location': 'Kanata',
#   'apply_link': 'https://jobs.cisco.com/jobs/ProjectDetail/Software-Engineer-Intern-Canada/1426800',
#   'description': 'Cisco Systems\n4.3\nSoftware Engineer (Intern) Canada\nKanata\nApply on employer site\nApply on employer site\nApplications are accepted until further notice.\nPlease note this posting is to advertise potential job opportunities. This exact role may not be open today but could open in the near future. When you apply, a Cisco representative may contact you directly if a relevant position opens.\nWho You’ll Work With\nOur hardworking team members are busy programming magic across the globe on teams such as Engineering, Information Technology, Supply Chain, Customer Experience, Security and Trust, etc.\nYou would play a crucial role in driving next-gen software innovations including cloud, mobile, desktop or security spaces. On any of these teams, you\'ll get hands-on experience working with applications that make technology accessible no matter what device they’re on. See the possibilities when creativity meets design and build solutions which will transform how we work, live, learn, and play.\nWhat You’ll Do\nOur software engineers are the gurus behind the scenes, ensuring all of our programs are easy to use and bug free. Using a keen eye, you’ll develop software and tools in support of many of our high-impact technology platforms such as operating systems, networks, databases and more. While we’re growing in the software business, you’ll still need to see the big picture and watch for hardware compatibility while even potentially influencing design.\nUnsure where to start? Apply and explore all of the possibilities in: Applications Development, Database Development, Embedded Networking and OS Development, IT, Security, Test & Quality, Web Services, etc.\nWho You Are\nA software developer who demonstrates exceptional communication and collaboration abilities, coupled with a genuine enthusiasm for tackling complex challenges. The ideal candidate will exhibit outstanding organizational skills and a keen aptitude for managing their time efficiently.\nAs a process-driven individual, you will have a fervent desire to streamline and enhance existing procedures. Your adeptness in time management will empower you to effectively prioritize tasks and deliver high-quality work within set deadlines.\nJoin our team and apply your passion for problem-solving to create innovative software solutions that make a difference.\nMinimum Qualifications\nIncluding but not limited to an upcoming graduate of a technical degree or certification program from a Technical Boot Camp, Apprenticeship, Community College or 4-Year University.\nActively enrolled in an educational program in Computer Science, Software Engineering, Computer Engineering, Electrical Engineering or related field\nUp-to-date on programming and scripting languages: C/C++, Python, and/or Java\nHands on QA, Testing, and/or Debugging skills\nAble to legally live and work in the country for which you’re applying and have an authorized internship with your school\nPreferred Qualifications\nKnowledge of Linux, Networking concepts, OS fundamentals, Embedded Development, and/or ML\nExperience with Databases, Web Application Development, and Web Services\nKnowledge in Computer Networking and/or Cybersecurity\nKnowledge of Cloud Platforms: AWS, Microsoft Azure, or Google Cloud\nWhy Cisco\n#WeAreCisco, where each person is unique, but we bring our talents to work as a team and make a difference powering an inclusive future for all.\nWe embrace digital, and help our customers implement change in their digital businesses. Some may think we’re “old” (40 years strong) and only about hardware, but we’re also a software company. And a security company. We even invented an intuitive network that adapts, predicts, learns and protects. No other company can do what we do – you can’t put us in a box!\nBut “Digital Transformation” is an empty buzz phrase without a culture that allows for innovation, creativity, and yes, even failure (if you learn from it.)\nDay to day, we focus on the give  ...
#   'timestamp': '2024-09-05 12:49:32'},
#  {'_id': ObjectId('66d9e18daef0eb3b303c2ccb'),
#   'title': 'C++ Software Developer Intern',
#   'company': 'Safe Software Inc.',
#   'location': 'Surrey',
#   'apply_link': 'https://recruiting.ultipro.ca/SAF5000SFSW/JobBoard/1a0223b9-a8a0-4790-ab46-bf6f3606be98/OpportunityDetail?opportunityId=aeab2173-4240-4fc7-8240-bf4e7e8ac5df&postingId=3b22a6ed-dead-45bf-9447-690299202859',
#   'description': 'Safe Software Inc.\n4.6\nC++ Software Developer Intern\nSurrey\nApply on employer site\nApply on employer site\nLocation: This opportunity has the ability to be hybrid in the Vancouver, BC Lower Mainland.\nDuration: January 6th 2025 - April 25th 2025\nBase Salary: Commensurate with Experience\nSalary Progression by Total Work Terms Completed:\nWork Term 1 (first work term): $22.50 pr/hr\nWork Term 2: $25.00 pr/hr\nWork Term 3: $27.50 pr/hr\nWork Term 4: $29.00 pr/hr\nWork term 5: $30.00 pr/hr\nWork term 6: $31.00 pr/h\nPlease note that employment may be contingent upon the successful completion of a Canadian criminal record check.\n\n\nApplication Instructions:\nPlease upload your application files in PDF format only.\nPlease submit a Resume, Cover letter and Transcript\nThis posting will remain open until the role has been filled, but we encourage you to apply as soon as possible. Applications will be reviewed on a rolling basis and shortlisted candidates will be contacted directly for interview requests.\n\nC++ Software Developer Intern\nSafe Software is looking for a C++ Software Developer Intern to join our Engine Product Development group to support the functionality of new and existing features in our FME product platform.\nAbout The Team\nOur Product Development department spans across our entire FME Platform (Form, Engine, Flow, Flow Hosted and Mobile) and is subdivided into specialized cross-functional teams that support the development cycle from end-to-end. Within your assigned development team, you may have the opportunity to work closely with developers, quality analysts, a product manager, and a UX/UI designer to assist with new feature development and see the software development life cycle from end-to-end. Our primary focus is to write high performance code that can scale with FME’s growing list of functionalities.\n\nWhat You’ll Be Doing\nAs a C++ Software Developer Intern, you’ll have the opportunity to:\nWrite and design readable, maintainable production-level code in C++\nAnalyze and debug complex issues and help resolve them\nParticipate and share ideas in daily team stand-up meetings\nCollaborate with other team members through peer code reviews and brainstorming sessions\nLearn and explore new and existing technologies during your day-to-day work term\nQualifications, Skills, and Competencies\nSafe Software evaluates applicants based on their passion and skill with technology. That said, having experience with some of the following areas is an asset.\nRequired skills\nTechnical skills\nProficient with C++ including modern features\nEffective communication skills to convey technical topics (synchronously and asynchronously)\nWorks well independently and in a team with minimal supervision\nSelf-motivated and eager to both teach and learn new skills\nAbility to work independently and ask questions as needed\nAbility to collaborate effectively and exchange meaningful feedback\nAbility to think analytically and propose solutions to solve problems\nDesired skills / Bonus points:\nExperience with Visual Studio\nExperience with Git/GitHub\nExperience with Computational Geometry\nExperience with floating-point error mitigation\nFamiliarity with Agile methodologies such as Kanban or Scrum\nExperience with Atlassian tools (e.g. Jira and Confluence)\nPrevious Co-op or related experience in software development is an asset\nStudents in their 3rd year or above (preferred)\nWhat You Can Expect\nWhen you choose an internship with Safe Software, you’re also choosing…\nMeaningful Work: Be a part of the solution. Get involved in hands-on projects that matter to you (and us) that challenge your critical thinking and help take your skills to the next level.\nA Supportive Environment: Feel empowered to share your ideas and implement them with high autonomy and support.\nMentorship: Learn from a team of experienced mentors and technical leaders who will support your development. 1 in 4 of our current staff st ...
#   'timestamp': '2024-09-05 12:49:32'}]

# %%
latest_jobs_list
