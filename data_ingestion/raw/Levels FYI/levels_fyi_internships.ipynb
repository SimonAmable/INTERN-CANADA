# %% [markdown]
# # Import nessacary libraries

# %%
# %pip install selenium
# %pip install pymongo
# %pip install beautifulsoup4

# %%
# import some basic python libaries (operating system, regular expressions, time)
import os
import re
import time
from datetime import datetime
import random
import requests
# import some selenium components to rememeneber by name
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import TimeoutException, NoSuchElementException, WebDriverException

# Import Load login credentials from .env file, make sure to pip install python-dotenv
#import mongoDB, we may add additional databases in the future for better 

from pymongo import MongoClient

from bs4 import BeautifulSoup

#import custom library

# %% [markdown]
# # Setup

# %%
# Create a MongoClient to the running mongod instance
client = MongoClient("mongodb://localhost:27017")
db = client["my_database"]
#Delete all documents in the collection before we start 
collection_levels_fyi = db['opportunities_levels_fyi']
# result = collection_levels_fyi.delete_many({})
# print(result.deleted_count, " documents deleted.")
url = r"https://www.levels.fyi/internships/?track=Software%20Engineer&timeframe=Summer%20-%202024"
#current tie for log name
timestamp = datetime.now().strftime('%Y_%m_%d_%H-%M-%S')

# %% [markdown]
# # Data Ingestion

# %%
#get all jobs and store them in a list of objects in mongo db
driver = webdriver.Chrome()
driver.get(url)
time.sleep(5)

job_description_section = WebDriverWait(driver, 5).until(EC.presence_of_element_located((By.ID, "internships-table")))
job_box_html = job_description_section.get_attribute('outerHTML')
# print (job_box_html)


#response = requests.get(url)
# soup = BeautifulSoup(response, 'html.parser')

driver.quit()

# %%
# Now we use soup to parse the html and get the data we need
test = requests.get(url, timeout= 5)
soup = BeautifulSoup(job_box_html, 'html.parser')
all_data = []

rows = soup.find_all('tr')
filtered_rows = []
tag = soup.a
for element in rows:
    if "Not Open" in element.text:
        continue
    else:
        filtered_rows.append(element)

print(len(filtered_rows))
# g
for item in filtered_rows:
    data = {}
    smaller_soup = BeautifulSoup(str(item), 'html.parser')
    # extract the data from the html and put into documents to deal with later

        #   GET THE LINK
    link = smaller_soup.find("a")
    if link and 'href' in link.attrs:
        href = link['href']
        link_text = link.text.strip()
       # print(f"Link: {href}")
        # print(href)
        #print(f"Text: {link_text}")
        # Only keep applying if the link look valid
        if "Apply" in link_text:
            data["href"] = href
        else:
            data["href"] = "NA"
            
    else:
        print("No <a> tag found in this element.")
        continue
    
    #title matches search term so we may want to keep it in a variable along side the urls we iterate to to get the job title

        #    GET THE SALARY
    salary = smaller_soup.find("div",class_= "salary-info")
    if salary:
        # print(salary)
        # print(salary.text)
        cleaned_salary_text = salary.text.rstrip().lstrip().replace("\n", "").replace("Apply", "").replace('Add Compensation',"NA")
        # print(cleaned_salary_text)
        data["salary"] = cleaned_salary_text

        #save info to object
    else:
        print("No salary found in this element.")


        #   GET THE LOCATION AND COMPANY
    location = smaller_soup.find("div", class_="media-body align-self-center")
    if location:
        # Split the text by newlines and strip any leading/trailing whitespace
        cleaned_parts = [part.strip() for part in location.text.split('\n') if part.strip()]
        company_name = cleaned_parts[0]  #company i think
        location = cleaned_parts[1] #loction i think

        
        
        
        if "-" in location:
            location_and_time_list = location.split("-")
            real_location = location_and_time_list[0]
            season = location_and_time_list[1]
            data["location"] = real_location
            data["season"] = season
        else: 
            data["location"] = location

        # print (real_location)
        # print (season)

        data["company"] = company_name
        #
    else:
        print("No location found in this element.")

        #   GET THE Details, we can parse the link with ai later to get a description if we want to explore that route.
    details = smaller_soup.find("td", class_="tags-th lfont m-3 py-3")
    if details:
        cleaned_details = details.text
        # print(cleaned_details)
        data['details'] = cleaned_details
    else:
        print("No details found in this element.")

    # data = {"details": details, "date": datetime.now()}
    # print(data)
    data["timestamp"] = timestamp
        # Try to insert the document
    collection_levels_fyi.insert_one(data)
    print(f"{data} successfully inserted into the database.")
    
    # print(smaller_soup.prettify)
    #print("\n\n")

# print(filtered_rows.text)
# all_jobs = soup.find_all( class_="media company-info-cell")
# print(len(all_jobs))
# print(all_jobs[0].prettify())
# Out:
# 142
# No <a> tag found in this element.
# No <a> tag found in this element.
# {'href': 'NA', 'salary': 'CA$217 / hrCA$37,567 / mo', 'location': 'Chicago, IL ', 'season': '  Summer / 2024', 'company': 'Radix Trading', 'details': '\nPhD\nCorporate housing, CA$33,865 sign-on bonus\n\nQuantitative Researcher\n\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced8294b2c895ef1cf5a')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'CA$183.66 / hrCA$31,834 / mo', 'location': 'Bala Cynwyd, PA ', 'season': '  Summer / 2024', 'company': 'SIG', 'details': '\nPhD\nCorporate housing, company provided transportation and relocation, CA$37,251 sign-on bonus\n\nQuantitative Researcher\n\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced8294b2c895ef1cf5b')} successfully inserted into the database.
# {'href': 'https://www.deshaw.com/careers/software-developer-intern-new-york-summer-2024-4803?ref=levels.fyi', 'salary': 'CA$171.93 / hrCA$29,801 / mo', 'location': 'New York City, NY ', 'season': '  Summer / 2024', 'company': 'D.E. Shaw', 'details': '\nPhD\nCorporate housing\n\nQuantitative Researcher\n\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced8294b2c895ef1cf5c')} successfully inserted into the database.
# {'href': 'https://optiver.com/working-at-optiver/career-opportunities/?_gl=1*rzd3uv*_up*MQ..&gclid=CjwKCAjw-7OlBhB8EiwAnoOEk9DE1HiDcs8Rzl5UWzLbMcHX2U_phUQrWHrl4A-soUm_cw8fMfCC3BoCcBcQAvD_BwE&numberposts=10&paged=1&search=intern&ref=levels.fyi', 'salary': 'CA$169 / hrCA$29,350 / mo', 'location': 'Chicago, IL ', 'season': '  Summer / 2024', 'company': 'Optiver', 'details': '\nUndergrad (Junior)\nCorporate housing, company provided transportation and relocation, CA$13,546 sign-on bonus\n\nQuantitative Trader\n\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced8294b2c895ef1cf5d')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'CA$162.81 / hrCA$28,220 / mo', 'location': 'New York City, NY ', 'season': '  Summer / 2024', 'company': 'Jane Street', 'details': '\nUndergrad (Junior)\nCA$4,064 / mo housing, CA$13,546 sign-on bonus\n\nQuantitative Trader\n\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced8294b2c895ef1cf5e')} successfully inserted into the database.
# {'href': 'https://www.citadelsecurities.com/careers/details/quantitative-researcher-phd-graduate-us-2/?ref=levels.fyi', 'salary': 'CA$145.6 / hrCA$25,240 / mo', 'location': 'New York City, NY ', 'season': '  Summer / 2024', 'company': 'Citadel Securities', 'details': '\nUndergrad (Junior)\nCorporate housing, company provided transportation, CA$948 relocation, CA$6,773 sign-on bonus\n\nQuantitative Researcher\n\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced8294b2c895ef1cf5f')} successfully inserted into the database.
# {'href': 'https://boards.greenhouse.io/schonfeld/jobs/5359234?ref=levels.fyi', 'salary': 'CA$143.28 / hrCA$24,834 / mo', 'location': 'New York City, NY ', 'season': '  Summer / 2024', 'company': 'Schonfeld', 'details': '\n\nQuantitative Researcher\n\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced8294b2c895ef1cf60')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'CA$130.24 / hrCA$22,576 / mo', 'location': 'Chicago, IL ', 'season': '  Summer / 2024', 'company': 'Akuna Capital', 'details': '\nCorporate housing, company provided relocation\n\nQuantitative Developer\n\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced8294b2c895ef1cf61')} successfully inserted into the database.
# {'href': 'https://careers.imc.com/us/en/job/REQ-02926/Software-Engineer-Intern-2024-2025-EXPRESSION-OF-INTEREST?ref=levels.fyi', 'salary': 'CA$128.94 / hrCA$22,351 / mo', 'location': 'Sydney, Australia ', 'season': '  Summer / 2024', 'company': 'IMC Trading', 'details': '\nUndergrad (Junior)\nCorpotate housing, CA$948 transportation, CA$813 relocation\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced8294b2c895ef1cf62')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'CA$123.47 / hrCA$21,401 / mo', 'location': 'Chicago, IL ', 'season': '  Summer / 2024', 'company': 'DRW', 'details': '\nCorporate housing, CA$33,865 sign-on bonus\n\nQuantitative Researcher\n\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced8294b2c895ef1cf63')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'CA$121.49 / hrCA$21,059 / mo', 'location': 'New York City, NY ', 'season': '  Summer / 2024', 'company': 'Amazon', 'details': '\nUndergrad (Junior)\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced8294b2c895ef1cf64')} successfully inserted into the database.
# {'href': 'https://www.goldmansachs.com/careers/students/programs/?ref=levels.fyi', 'salary': 'CA$104.62 / hrCA$18,134 / mo', 'location': 'New York City, NY ', 'season': '  Summer / 2024', 'company': 'Goldman Sachs', 'details': '\nUndergrad (Senior)\nCA$3,116 / mo housing, CA$542 transportation\n\nQuantitative Researcher\n\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced8294b2c895ef1cf65')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'CA$97.69 / hrCA$16,934 / mo', 'location': 'Boston, MA ', 'season': '  Summer / 2024', 'company': 'Weiss Asset Management', 'details': '\nUndergrad (Junior)\nCA$13,546 Housing\n\nQuantitative Researcher\n\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced8294b2c895ef1cf66')} successfully inserted into the database.
# {'href': 'https://university-uber.icims.com/jobs/125074/2024-software-engineering-internship---amsterdam/job?ref=levels.fyi', 'salary': 'CA$91 / hrCA$15,731 / mo', 'location': 'San Francisco, CA ', 'season': '  Summer / 2024', 'company': 'Uber', 'details': '\nPhD\nCA$2,303 / mo housing, company provided transportation and relocation\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced8294b2c895ef1cf67')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'CA$88.56 / hrCA$15,352 / mo', 'location': 'New York City, NY ', 'season': '  Summer / 2024', 'company': 'Capital One', 'details': '\nUndergrad (Junior)\nCA$2,258 / mo housing\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced8294b2c895ef1cf68')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'CA$88.25 / hrCA$15,297 / mo', 'location': 'New York City, NY ', 'season': '  Summer / 2024', 'company': 'Facebook', 'details': '\nUndergrad (Junior)\nCA$5,283 Housing, CA$203 transportation, company provided relocation\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced8294b2c895ef1cf69')} successfully inserted into the database.
# {'href': 'https://app.ripplematch.com/v2/public/job/107e5590/details?from_page=company_branded_page&ref=levels.fyi', 'salary': 'CA$88 / hrCA$15,262 / mo', 'location': 'San Francisco, CA ', 'season': '  Summer / 2024', 'company': 'Notion', 'details': '\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced8294b2c895ef1cf6a')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'CA$82.16 / hrCA$14,241 / mo', 'location': 'Santa Clara, CA ', 'season': '  Summer / 2024', 'company': 'AWS', 'details': '\nCompany provided relocation\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced8294b2c895ef1cf6b')} successfully inserted into the database.
# {'href': 'https://jobs.ashbyhq.com/ramp/16ebfcfc-467b-40e5-b23e-a4d95db05539?ref=levels.fyi', 'salary': 'CA$81 / hrCA$14,088 / mo', 'location': 'New York City, NY ', 'season': '  Summer / 2024', 'company': 'Ramp', 'details': '\nCA$5,418 lumpsum housing\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced8294b2c895ef1cf6c')} successfully inserted into the database.
# {'href': 'https://app.ripplematch.com/v2/public/job/c7d28bdf/details?from_page=company_branded_page&ref=levels.fyi', 'salary': 'CA$81 / hrCA$14,088 / mo', 'location': 'New York City, NY ', 'season': '  Summer / 2024', 'company': 'Reddit', 'details': '\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced8294b2c895ef1cf6d')} successfully inserted into the database.
# {'href': 'https://stripe.com/jobs/search?query=intern&ref=levels.fyi', 'salary': 'CA$81 / hrCA$14,088 / mo', 'location': 'New York City, NY ', 'season': '  Summer / 2024', 'company': 'Stripe', 'details': '\nUndergrad (Sophomore)\nCA$6,773 Housing, CA$677 / mo transportation, CA$2,167 relocation\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced8294b2c895ef1cf6e')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'CA$79 / hrCA$13,618 / mo', 'location': 'San Fransisco, CA ', 'season': '  Summer / 2024', 'company': 'Databricks', 'details': '\nUndergrad (Junior)\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced8294b2c895ef1cf6f')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'CA$78.15 / hrCA$13,546 / mo', 'location': 'Colorado Springs, CO ', 'season': '  Summer / 2024', 'company': 'Air Force Research Laboratory', 'details': '\nUndergrad (Senior)\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced8294b2c895ef1cf70')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'CA$77 / hrCA$13,383 / mo', 'location': 'New York City, NY ', 'season': '  Summer / 2024', 'company': 'BlackRock', 'details': '\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced8294b2c895ef1cf71')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'CA$76.85 / hrCA$13,320 / mo', 'location': 'New York City, NY ', 'season': '  Summer / 2024', 'company': 'Google', 'details': '\nUndergrad (Junior)\nCA$3,160 / mo housing, CA$1,355 Transportation\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced8294b2c895ef1cf72')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'CA$76.59 / hrCA$13,275 / mo', 'location': 'New York City, NY ', 'season': '  Summer / 2024', 'company': 'Palantir', 'details': '\nUndergrad (Junior)\nCA$3,386 / mo housing, flights covered\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced8294b2c895ef1cf73')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'CA$76.2 / hrCA$13,207 / mo', 'location': 'Chicago, IL ', 'season': '  Summer / 2024', 'company': 'Balyasny Asset Management', 'details': '\nUndergrad (Junior)\nCA$10,159 sign-on bonus\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced8294b2c895ef1cf74')} successfully inserted into the database.
# {'href': 'https://verily.com/about-us/careers/open-roles?job_id=5600360&ref=levels.fyi', 'salary': 'CA$75.55 / hrCA$13,095 / mo', 'location': 'San Francisco, CA ', 'season': '  Summer / 2024', 'company': 'Verily Life Sciences', 'details': '\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced8294b2c895ef1cf75')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'CA$74.9 / hrCA$12,982 / mo', 'location': 'Boston, MA ', 'season': '  Summer / 2024', 'company': 'Gecko Robotics', 'details': '\nUndergrad (Junior)\nCA$2,258 Housing\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced8294b2c895ef1cf76')} successfully inserted into the database.
# {'href': 'https://boards.greenhouse.io/affirm/jobs/5958177003?ref=levels.fyi', 'salary': 'CA$75 / hrCA$12,913 / mo', 'location': 'New York City, NY ', 'season': '  Summer / 2024', 'company': 'Affirm', 'details': '\nCA$4,064 Relocation\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced8294b2c895ef1cf77')} successfully inserted into the database.
# {'href': 'https://www.ziprecruiter.com/c/ZipRecruiter/Job/Software-Engineer-Intern/-in-Santa-Monica,CA?jid=f331da90344f3100&ref=levels.fyi', 'salary': 'CA$75 / hrCA$12,913 / mo', 'location': 'Santa Monica, CA ', 'season': '  Summer / 2024', 'company': 'ZipRecruiter', 'details': '\nUndergrad (Junior)\nCA$3,386 / mo housing, paid flights,CA$135 wellness, hybrid \n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced8294b2c895ef1cf78')} successfully inserted into the database.
# {'href': 'https://jobs.lever.co/zoox/52e266b7-a901-45b8-9197-5723f96176dd?ref=levels.fyi', 'salary': 'CA$74.25 / hrCA$12,869 / mo', 'location': 'Foster City, CA ', 'season': '  Summer / 2024', 'company': 'Zoox', 'details': '\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced8294b2c895ef1cf79')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'CA$73 / hrCA$12,679 / mo', 'location': 'New York City, NY ', 'season': '  Summer / 2024', 'company': 'Rippling', 'details': '\nUndergrad (Junior)\nCA$2,709 / mo housing, CA$1,016 relocation\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced8294b2c895ef1cf7a')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'CA$81 / hrCA$12,445 / mo', 'location': 'San Francisco, CA ', 'season': '  Summer / 2024', 'company': 'Salesforce', 'details': '\nMasters\nCA$5,643 / mo housing\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced8294b2c895ef1cf7b')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'CA$71.63 / hrCA$12,416 / mo', 'location': 'New York City, NY ', 'season': '  Summer / 2024', 'company': 'JPMorgan Chase', 'details': '\nUndergrad (Junior)\nCA$3,386 sign-on bunus \n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced8294b2c895ef1cf7c')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'CA$71.63 / hrCA$12,416 / mo', 'location': 'New York City, NY ', 'season': '  Summer / 2024', 'company': 'Morgan Stanley', 'details': '\nUndergrad (Junior)\nCA$2,709 Housing, CA$677 transportation\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced8294b2c895ef1cf7d')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'CA$71.63 / hrCA$12,416 / mo', 'location': 'New York City, NY ', 'season': '  Summer / 2024', 'company': 'RBC', 'details': '\nUndergrad (Junior)\n\nQuantitative Analyst\n\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced8294b2c895ef1cf7e')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'CA$70.8 / hrCA$12,273 / mo', 'location': 'New York City, NY ', 'season': '  Summer / 2024', 'company': 'Microsoft', 'details': '\nUndergrad (Junior)\nCA$4,515 / mo housing, CA$1,626 relocation, flights covered\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced8294b2c895ef1cf7f')} successfully inserted into the database.
# {'href': 'https://app.ripplematch.com/v2/public/job/e9a5081a/details?from_page=company_branded_page&ref=levels.fyi', 'salary': 'CA$70.55 / hrCA$12,229 / mo', 'location': 'New York City, NY ', 'season': '  Summer / 2024', 'company': 'Datadog', 'details': '\nCA$8,128 housing, company provided relocation, company lunch every Monday, Wednesday and Friday\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced8294b2c895ef1cf80')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'CA$70 / hrCA$12,209 / mo', 'location': 'San Francisco, CA ', 'season': '  Summer / 2024', 'company': 'Bloomberg', 'details': '\nUndergrad (Junior)\nCA$9,753 Housing, CA$2,709 relocation\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced8294b2c895ef1cf81')} successfully inserted into the database.
# {'href': 'https://www.pinterestcareers.com/en/jobs/5666542/software-engineering-intern-2024-toronto/?gh_jid=5666542&ref=levels.fyi', 'salary': 'CA$70.33 / hrCA$12,191 / mo', 'location': 'Remote ', 'season': '  Summer / 2024', 'company': 'Pinterest', 'details': '\nMasters\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced8294b2c895ef1cf82')} successfully inserted into the database.
# {'href': 'https://careers.adobe.com/us/en/job/R139304/2024-Intern-Software-Engineer?ref=levels.fyi', 'salary': 'CA$69 / hrCA$11,975 / mo', 'location': 'San Francisco, CA ', 'season': '  Summer / 2024', 'company': 'Adobe', 'details': '\nUndergrad (Junior)\nCA$10,837 Housing, CA$135 transportation, CA$406 stipend, free lunch\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced8294b2c895ef1cf83')} successfully inserted into the database.
# {'href': 'https://nomuracampus.tal.net/vx/lang-en-GB/mobile-0/appcentre-ext/brand-4/xf-3348347fc789/candidate/jobboard/vacancy/1/adv/?ref=levels.fyi', 'salary': 'CA$68.38 / hrCA$11,853 / mo', 'location': 'New York City, NY ', 'season': '  Summer / 2024', 'company': 'Nomura', 'details': '\nMasters\nCA$1,355 / MO Housing\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced8294b2c895ef1cf84')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'CA$68 / hrCA$11,740 / mo', 'location': 'Remote Canada ', 'season': '  Summer / 2024', 'company': '1Password', 'details': '\nUndergrad (Junior)\nCA$339 WFH stipend, 3 years of 1Password subscription\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced8294b2c895ef1cf85')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'CA$68 / hrCA$11,740 / mo', 'location': 'Toronto, Canada ', 'season': '  Summer / 2024', 'company': 'Amazon Robotics', 'details': '\nUndergrad (Junior)\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced8294b2c895ef1cf86')} successfully inserted into the database.
# {'href': 'https://www.coinbase.com/es/careers/positions/5442125?ref=levels.fyi', 'salary': 'CA$68 / hrCA$11,740 / mo', 'location': 'Mountain View, CA ', 'season': '  Summer / 2024', 'company': 'Coinbase', 'details': '\nUndergrad (Junior)\nCA$3,160 / mo housing\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced8294b2c895ef1cf87')} successfully inserted into the database.
# {'href': 'https://ea.gr8people.com/jobs/179701/software-engineer-intern?ref=levels.fyi', 'salary': 'CA$68 / hrCA$11,740 / mo', 'location': 'Redwood City, CA ', 'season': '  Summer / 2024', 'company': 'Electronic Arts', 'details': '\nUndergrad (Junior)\nCA$677 WFH Stipend housing\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced8294b2c895ef1cf88')} successfully inserted into the database.
# {'href': 'https://gen.wd1.myworkdayjobs.com/en-US/careers/details/IT-Summer-Intern_53116?q=intern&ref=levels.fyi', 'salary': 'CA$68 / hrCA$11,740 / mo', 'location': 'Mountain View, CA ', 'season': '  Summer / 2024', 'company': 'Gen Digital', 'details': '\nUndergrad (Sophomore)\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced8294b2c895ef1cf89')} successfully inserted into the database.
# {'href': 'https://careers.gehealthcare.com/global/en/job/R4006675/Software-Engineer-Intern?ref=levels.fyi', 'salary': 'CA$68 / hrCA$11,740 / mo', 'location': 'Bellevue, WA ', 'season': '  Summer / 2024', 'company': 'GE Healthcare', 'details': '\nUndergrad (Junior)\nCA$1,355 / mo housing, company provided relocation, hybrid\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced8294b2c895ef1cf8a')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'CA$66 / hrCA$11,505 / mo', 'location': 'San Diego, CA ', 'season': '  Summer / 2024', 'company': 'Qualcomm', 'details': '\nUndergrad (Sophomore)\nCompany Provided Relocation\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced8294b2c895ef1cf8b')} successfully inserted into the database.
# {'href': 'https://jobs.ubs.com/TGnewUI/Search/home/HomeWithPreLoad?partnerid=25008&siteid=5131&PageType=searchResults&SearchType=linkquery&LinkID=6166&ref=levels.fyi#keyWordSearch=&locationSearch=', 'salary': 'CA$65.13 / hrCA$11,289 / mo', 'location': 'New York City, NY ', 'season': '  Summer / 2024', 'company': 'UBS', 'details': '\nUndergrad (Junior)\nCA$2,709 / mo housing\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced8294b2c895ef1cf8c')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'CA$65.12 / hrCA$11,286 / mo', 'location': 'New York City, NY ', 'season': '  Summer / 2024', 'company': 'BNY Mellon', 'details': '\nUndergrad (Junior)\nCA$4,064 Sign-on bonus\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced8294b2c895ef1cf8d')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'CA$64 / hrCA$11,036 / mo', 'location': 'Santa Clara, CA ', 'season': '  Summer / 2024', 'company': 'Apple', 'details': '\nUndergrad (Junior)\nCA$4,470 / mo housing, company provided relocation\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced8294b2c895ef1cf8e')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'CA$64 / hrCA$11,036 / mo', 'location': 'New York City, NY ', 'season': '  Summer / 2024', 'company': 'SAP', 'details': '\nUndergrad (Senior)\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced8294b2c895ef1cf8f')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'CA$62.51 / hrCA$10,835 / mo', 'location': 'Mountain View, CA ', 'season': '  Summer / 2024', 'company': 'Google STEP', 'details': '\nCA$9,482 Housing, CA$4,064 relocation\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced8294b2c895ef1cf90')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'CA$62 / hrCA$10,800 / mo', 'location': 'San Francisco, CA ', 'season': '  Summer / 2024', 'company': 'Autodesk', 'details': '\nUndergrad (Junior)\nCA$1,355 Transportation\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced8294b2c895ef1cf91')} successfully inserted into the database.
# {'href': 'https://eeho.fa.us2.oraclecloud.com/hcmUI/CandidateExperience/en/sites/CX_1/requisitions?keyword=engineering+intern&lastSelectedFacet=AttributeChar4&selectedFlexFieldsFacets=%22AttributeChar4%7CStudent%2FIntern%22&selectedLocationsFacet=300000000149325&selectedPostingDatesFacet=30&ref=levels.fyi', 'salary': 'CA$62 / hrCA$10,800 / mo', 'location': 'Seattle, WA ', 'season': '  Summer / 2024', 'company': 'Oracle', 'details': '\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced8294b2c895ef1cf92')} successfully inserted into the database.
# {'href': 'https://bankcampuscareers.tal.net/vx/lang-en-GB/mobile-0/brand-4/xf-91c0e92d74a1/candidate/so/pm/1/pl/1/opp/10165-Global-Technology-Summer-Analyst-Program-2024/en-GB?ref=levels.fyi', 'salary': 'CA$61.6 / hrCA$10,684 / mo', 'location': 'Chicago, IL ', 'season': '  Summer / 2024', 'company': 'Bank of America', 'details': '\nCA$4,606 sign-on bonus\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced8294b2c895ef1cf93')} successfully inserted into the database.
# {'href': 'https://cadence.wd1.myworkdayjobs.com/en-US/Univ_Careers/details/Software-Engineering-Intern_R45062?q=intern&ref=levels.fyi', 'salary': 'CA$61 / hrCA$10,566 / mo', 'location': 'San Jose, CA ', 'season': '  Summer / 2024', 'company': 'Cadence', 'details': '\nCA$6,773 Relocation\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cf94')} successfully inserted into the database.
# {'href': 'https://careers.draftkings.com/jobs/?search=intern&pagesize=20&ref=levels.fyi', 'salary': 'CA$61 / hrCA$10,566 / mo', 'location': 'Boston, MA ', 'season': '  Summer / 2024', 'company': 'DraftKings', 'details': '\nUndergrad (Junior)\nCorporate housing, CA$13,546 Sign-On Bonus \n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cf95')} successfully inserted into the database.
# {'href': 'https://eyglobal.yello.co/job_boards/c1riT--B2O-KySgYWsZO1Q?locale=en&ref=levels.fyi', 'salary': 'CA$61 / hrCA$10,566 / mo', 'location': 'Chicago, IL ', 'season': '  Summer / 2024', 'company': 'Ernst & Young', 'details': '\nUndergrad (Junior)\nCompany provided transportation\n\nTech Consulting\n\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cf96')} successfully inserted into the database.
# {'href': 'https://careers.juniper.net/?ref=levels.fyi#/jobdescription?jid=1009975', 'salary': 'CA$61 / hrCA$10,566 / mo', 'location': 'Westford, MA ', 'season': '  Summer / 2024', 'company': 'Juniper Networks', 'details': '\nUndergrad (Junior)\nCA$6,096 Relocation\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cf97')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'CA$59.79 / hrCA$10,363 / mo', 'location': 'Charlottesville, VA ', 'season': '  Summer / 2024', 'company': 'Leidos', 'details': '\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cf98')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'CA$60 / hrCA$10,331 / mo', 'location': 'New York City, NY ', 'season': '  Summer / 2024', 'company': 'Tiktok', 'details': '\n\nCybersecurity\n\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cf99')} successfully inserted into the database.
# {'href': 'https://boards.greenhouse.io/instawork/jobs/4362259006?ref=levels.fyi', 'salary': 'CA$58.61 / hrCA$10,159 / mo', 'location': 'San Francisco, CA ', 'season': '  Summer / 2024', 'company': 'Instawork', 'details': '\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cf9a')} successfully inserted into the database.
# {'href': 'https://careers.thetradedesk.com/us/en/job/REQ-5795/2024-Software-Engineering-Intern-North-America?ref=levels.fyi', 'salary': 'CA$58 / hrCA$10,096 / mo', 'location': 'Los Angeles, CA ', 'season': '  Summer / 2024', 'company': 'The Trade Desk', 'details': '\nUndergrad (Junior)\nCA$2,709 / mo housing, CA$135 / quarter wellness, CA$102/ mo phone bill\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cf9b')} successfully inserted into the database.
# {'href': 'https://jobs.battelle.org/us/en/search-results?keywords=intern&ref=levels.fyi', 'salary': 'CA$57 / hrCA$9,861 / mo', 'location': 'Columbus, OH ', 'season': '  Summer / 2024', 'company': 'Battelle', 'details': '\nUndergrad (Senior)\nCA$1,355 / mo housing\n\nCyber Security\n\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cf9c')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'CA$57 / hrCA$9,861 / mo', 'location': 'Boulder, CO ', 'season': '  Summer / 2024', 'company': 'Splunk', 'details': '\nUndergrad (Junior)\nCA$8,128 Housing, CA$1,016 transportation\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cf9d')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'CA$56 / hrCA$9,627 / mo', 'location': 'Washington, DC ', 'season': '  Summer / 2024', 'company': 'Bytedance', 'details': '\nUndergrad (Junior)\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cf9e')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'CA$56 / hrCA$9,627 / mo', 'location': 'New York City, NY ', 'season': '  Summer / 2024', 'company': 'PwC', 'details': '\nUndergrad (Junior)\n\nTechnology Consultant\n\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cf9f')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'CA$54 / hrCA$9,391 / mo', 'location': 'Chevy Chase, MD ', 'season': '  Summer / 2024', 'company': 'Geico', 'details': '\nUndergrad (Sophomore)\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfa0')} successfully inserted into the database.
# {'href': 'https://gn.wd3.myworkdayjobs.com/en-US/JabraCareers/details/Software-Intern--Onsite-_R21049?q=intern&ref=levels.fyi', 'salary': 'CA$54 / hrCA$9,391 / mo', 'location': 'Cupertino, CA ', 'season': '  Summer / 2024', 'company': 'Jabra', 'details': '\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfa1')} successfully inserted into the database.
# {'href': 'https://www.marketaxess.com/careers/current-openings/detail/software-engineering-intern-2024-4375574006?gh_jid=4297752006&ref=levels.fyi', 'salary': 'CA$54 / hrCA$9,391 / mo', 'location': 'New York City, NY ', 'season': '  Summer / 2024', 'company': 'MarketAxess', 'details': '\nUndergrad (Senior)\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfa2')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'CA$54 / hrCA$9,391 / mo', 'location': 'Toronto, Canada ', 'season': '  Summer / 2024', 'company': 'Shopify', 'details': '\nUndergrad (Junior)\nCA$948 / mo housing\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfa3')} successfully inserted into the database.
# {'href': 'https://jobs.disneycareers.com/search-jobs/intern/391-28648/1?glat=59.93863&glon=30.31413&ref=levels.fyi', 'salary': 'CA$54 / hrCA$9,391 / mo', 'location': 'Orlando, FL ', 'season': '  Summer / 2024', 'company': 'Walt Disney Company', 'details': '\nUndergrad (Junior)\nCorporate housing, company provided relocation, CA$6,773 sign-on bonus\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfa4')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'CA$53 / hrCA$9,157 / mo', 'location': 'Vancouver, Canada ', 'season': '  Summer / 2024', 'company': 'Nvidia', 'details': '\nUndergrad (Senior)\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfa5')} successfully inserted into the database.
# {'href': 'https://jobs.dell.com/en/job/texas/software-engineer-c-windows-agent-intern/375/64371817072?ref=levels.fyi', 'salary': 'CA$52.03 / hrCA$9,019 / mo', 'location': 'Houston, TX ', 'season': '  Summer / 2024', 'company': 'Dell', 'details': '\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfa6')} successfully inserted into the database.
# {'href': 'https://www.medidata.com/en/careers/medidata-ai-software-engineer-intern-537290/job/?ref=levels.fyi', 'salary': 'CA$50 / hrCA$8,687 / mo', 'location': 'New York City, NY ', 'season': '  Summer / 2024', 'company': 'Dassault Systemes', 'details': '\nCA$4,741 sign-on bonus\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfa7')} successfully inserted into the database.
# {'href': 'https://stcareers.talent-soft.com/job/job-software-algorithms-development-internship-m-f_37674.aspx?ref=levels.fyi', 'salary': 'CA$49.46 / hrCA$8,572 / mo', 'location': 'Santa Clara, CA ', 'season': '  Summer / 2024', 'company': 'STMicroelectronics', 'details': '\nUndergrad (Junior)\nCA$406 / mo transportation\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfa8')} successfully inserted into the database.
# {'href': 'https://globalfoundries.wd1.myworkdayjobs.com/en-US/External/jobs?q=intern&ref=levels.fyi', 'salary': 'CA$45 / hrCA$8,453 / mo', 'location': 'Hartford, CT ', 'season': '  Summer / 2024', 'company': 'Global Atlantic Financial Group', 'details': '\nUndergrad (Junior)\nCA$2,709 Relocation\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfa9')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'CA$47.98 / hrCA$8,317 / mo', 'location': 'Cedar Rapids, IA ', 'season': '  Summer / 2024', 'company': 'Collins Aerospace', 'details': '\nUndergrad (Junior)\nCA$677 / mo housing, CA$5,418 relocation\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfaa')} successfully inserted into the database.
# {'href': 'https://hdjq.fa.us2.oraclecloud.com/hcmUI/CandidateExperience/en/sites/CX_1/requisitions?keyword=intern&mode=location&ref=levels.fyi', 'salary': 'CA$47 / hrCA$8,218 / mo', 'location': 'Austin, TX ', 'season': '  Summer / 2024', 'company': 'Emerson', 'details': '\nUndergrad (Junior)\nCA$2,032 / mo housing\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfab')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'CA$47 / hrCA$8,218 / mo', 'location': 'Westlake, TX ', 'season': '  Summer / 2024', 'company': 'Fidelity Investments', 'details': '\nUndergrad (Junior)\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfac')} successfully inserted into the database.
# {'href': 'https://careers.moodys.com/job/19879635/ma-summer-intern-kyc-software-engineering-associate-london-gb/?ref=levels.fyi', 'salary': 'CA$47 / hrCA$8,218 / mo', 'location': 'Bellevue, WA ', 'season': '  Summer / 2024', 'company': "Moody's Corporation", 'details': '\nMasters\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfad')} successfully inserted into the database.
# {'href': 'https://jobs.newyorklife.com/job/New-York-2024-Technology-Summer-Internship-Program-NY-10001/1055772100/?ref=levels.fyi', 'salary': 'CA$47 / hrCA$8,218 / mo', 'location': 'New York City, NY ', 'season': '  Summer / 2024', 'company': 'New York Life Insurance', 'details': '\nCA$2,709 lumpsum housing\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfae')} successfully inserted into the database.
# {'href': 'https://jobs.yum.com/jobs/general/chicago-il-united-states/engineering-intern-pos-platform/2835?ref=levels.fyi', 'salary': 'CA$47 / hrCA$8,218 / mo', 'location': 'Remote ', 'season': '  Summer / 2024', 'company': 'Yum! Brands', 'details': '\nUndergrad (Senior)\nCA$4,741 sign-on bonus \n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfaf')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'CA$46 / hrCA$7,983 / mo', 'location': 'Cincinnati, Ohio ', 'season': '  Summer / 2024', 'company': 'Siemens', 'details': '\nUndergrad (Junior)\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfb0')} successfully inserted into the database.
# {'href': 'https://boards.greenhouse.io/spacex/jobs/7268802002?gh_jid=7268802002&ref=levels.fyi', 'salary': 'CA$46 / hrCA$7,983 / mo', 'location': 'Hawthorne, CA ', 'season': '  Summer / 2024', 'company': 'SpaceX', 'details': '\nUndergrad (Junior)\nCA$1,355 housing, CA$677 transportation\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfb1')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'CA$45.72 / hrCA$7,924 / mo', 'location': 'Austin, TX ', 'season': '  Summer / 2024', 'company': 'Tesla', 'details': '\nUndergrad (Freshman)\nCA$3,793 Housing, flights covered\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfb2')} successfully inserted into the database.
# {'href': 'https://careers.unitedhealthgroup.com/job-search-results/?keyword=optum+intern&parent_category%5B%5D=Optum&ref=levels.fyi', 'salary': 'CA$45 / hrCA$7,748 / mo', 'location': 'Boston, MA ', 'season': '  Summer / 2024', 'company': 'Optum', 'details': '\nUndergrad (Junior)\nCorporate housing, flights covered\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfb3')} successfully inserted into the database.
# {'href': 'https://jobs.smartrecruiters.com/WesternDigital/743999984673543-summer-intern-2024-software-engineering-internship-firmware?ref=levels.fyi', 'salary': 'CA$45 / hrCA$7,748 / mo', 'location': 'Longmont, CO ', 'season': '  Summer / 2024', 'company': 'Western Digital', 'details': '\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfb4')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'CA$43.96 / hrCA$7,620 / mo', 'location': 'Morrisville, NC ', 'season': '  Summer / 2024', 'company': 'Cisco', 'details': '\nUndergrad (Junior)\nCA$10,837 Sign-on bonus\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfb5')} successfully inserted into the database.
# {'href': 'https://www.lexisnexis.com/systems/careers/job-search.html?k=intern&ref=levels.fyi', 'salary': 'CA$43 / hrCA$7,514 / mo', 'location': 'Raleigh, NC ', 'season': '  Summer / 2024', 'company': 'LexisNexis', 'details': '\nMasters\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfb6')} successfully inserted into the database.
# {'href': 'https://www.quadeye.com/careers/?ref=levels.fyi', 'salary': 'CA$42.4 / hrCA$7,349 / mo', 'location': 'Gurgaon ', 'season': '  Summer / 2024', 'company': 'Quadeye', 'details': '\nUndergrad (Junior)\nCA$3,386 Housing\n\nQuantitative Researcher\n\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfb7')} successfully inserted into the database.
# {'href': 'https://corporate.visa.com/en/jobs/REF65615I?ref=levels.fyi', 'salary': 'CA$42 / hrCA$7,278 / mo', 'location': 'Austin, TX ', 'season': '  Summer / 2024', 'company': 'Visa', 'details': '\nCorporate housing, CA$5,418 Relocation, CA$474 transportation\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfb8')} successfully inserted into the database.
# {'href': 'https://jobs.lever.co/actian/15bc140e-0f26-4371-b703-96bc4a08b43e?ref=levels.fyi', 'salary': 'CA$41 / hrCA$7,044 / mo', 'location': 'Remote ', 'season': '  Summer / 2024', 'company': 'Actian', 'details': '\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfb9')} successfully inserted into the database.
# {'href': 'https://simoncomputing.applicantpro.com/jobs/2563142?ref=levels.fyi', 'salary': 'CA$41 / hrCA$7,044 / mo', 'location': 'Alexandria, VA ', 'season': '  Summer / 2024', 'company': 'Simon Computing', 'details': '\nUndergrad (Sophomore)\nCorporate housing\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfba')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'CA$41 / hrCA$7,044 / mo', 'location': 'Bentonville, AR ', 'season': '  Summer / 2024', 'company': 'Walmart', 'details': '\nCompany Provided Relocation\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfbb')} successfully inserted into the database.
# {'href': 'https://jobs.boeing.com/category/internship-jobs/185/9287/1?ref=levels.fyi', 'salary': 'CA$40.2 / hrCA$6,973 / mo', 'location': 'Arlington, VA ', 'season': '  Summer / 2024', 'company': 'Boeing', 'details': '\nUndergrad (Junior)\nCA$11,920 Housing, CA$1,355 transportation, company provided relocation\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfbc')} successfully inserted into the database.
# {'href': 'https://careers.caterpillar.com/en/jobs/?searchTerm=intern&pagesize=20&ref=levels.fyi#results', 'salary': 'CA$40 / hrCA$6,926 / mo', 'location': 'Mossville, IL ', 'season': '  Summer / 2024', 'company': 'Caterpillar', 'details': '\nUndergrad (Junior)\nCA$1,355 / mo housing, CA$271 relocation\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfbd')} successfully inserted into the database.
# {'href': 'https://careers.moog.com/jobs/summer-2024-software-engineering-internship-11116?ref=levels.fyi', 'salary': 'CA$40 / hrCA$6,926 / mo', 'location': 'Elma, NY ', 'season': '  Summer / 2024', 'company': 'Moog', 'details': '\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfbe')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'CA$39 / hrCA$6,810 / mo', 'location': 'Chicago, IL ', 'season': '  Summer / 2024', 'company': '84.51 Degrees', 'details': '\nUndergrad (Sophomore)\nCorporate housing, company provided relocation\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfbf')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'CA$38 / hrCA$6,574 / mo', 'location': 'Plano, TX ', 'season': '  Summer / 2024', 'company': 'Ericsson', 'details': '\nUndergrad (Sophomore)\nCA$1,626 / mo housing, CA$2,709 relocation, hybrid\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfc0')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'CA$37 / hrCA$6,340 / mo', 'location': 'San Diego, CA ', 'season': '  Summer / 2024', 'company': 'Booz Allen Hamilton', 'details': '\nUndergrad (Sophomore)\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfc1')} successfully inserted into the database.
# {'href': 'https://careers.honeywell.com/us/en/job/req412191/Computer-Software-Engineer-Computer-Science-Summer-2024-Internship?ref=levels.fyi', 'salary': 'CA$37 / hrCA$6,340 / mo', 'location': 'Atlanta, GA ', 'season': '  Summer / 2024', 'company': 'Honeywell', 'details': '\nCorporate housing\n\nCybersecurity\n\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfc2')} successfully inserted into the database.
# {'href': 'https://www.myrocketcareer.com/listjobs/?keyword=intern&ref=levels.fyi', 'salary': 'CA$36.24 / hrCA$6,281 / mo', 'location': 'Detroit, MI ', 'season': '  Summer / 2024', 'company': 'Rocket Companies', 'details': '\nMasters\nCorporate housing\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfc3')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'CA$36.2 / hrCA$6,269 / mo', 'location': 'Chicago, IL ', 'season': '  Summer / 2024', 'company': 'Motorola', 'details': '\nUndergrad (Junior)\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfc4')} successfully inserted into the database.
# {'href': 'https://careers-hexagonpositioning.icims.com/jobs/2571/embedded-engineering-intern/job?ref=levels.fyi', 'salary': 'CA$34 / hrCA$5,869 / mo', 'location': 'Orlando, FL ', 'season': '  Summer / 2024', 'company': 'Hexagon', 'details': '\nUndergrad (Junior)\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfc5')} successfully inserted into the database.
# {'href': 'https://careers.pnnl.gov/jobs?keywords=intern&ref=levels.fyi', 'salary': 'CA$34 / hrCA$5,869 / mo', 'location': 'Seattle, WA ', 'season': '  Summer / 2024', 'company': 'PNNL', 'details': '\nUndergrad (Junior)\nCompany Provided Relocation\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfc6')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'CA$33.23 / hrCA$5,760 / mo', 'location': 'Markham, Canada ', 'season': '  Summer / 2024', 'company': 'AMD', 'details': '\nUndergrad (Junior)\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfc7')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'CA$33.2 / hrCA$5,753 / mo', 'location': 'Orlando, FL ', 'season': '  Summer / 2024', 'company': 'Lockheed Martin', 'details': '\nUndergrad (Junior)\nCA$2,980 / mo housing\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfc8')} successfully inserted into the database.
# {'href': 'https://careers.dovercorporation.com/search/?createNewAlert=false&q=intern&locationsearch=&optionsFacetsDD_department=&optionsFacetsDD_facility=&optionsFacetsDD_customfield3=&optionsFacetsDD_customfield4=&ref=levels.fyi', 'salary': 'CA$33 / hrCA$5,635 / mo', 'location': 'Dallas, TX ', 'season': '  Summer / 2024', 'company': 'Dover', 'details': '\nUndergrad (Senior)\nCA$1,806 / mo housing\n\nIT\n\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfc9')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'CA$33 / hrCA$5,635 / mo', 'location': 'Cincinnati, OH ', 'season': '  Summer / 2024', 'company': 'Kroger', 'details': '\nUndergrad (Junior)\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfca')} successfully inserted into the database.
# {'href': 'https://komatsu.jobs/job/Warrendale-Robotics-Software-Intern-PA-15086/1207355200/?ref=levels.fyi', 'salary': 'CA$31 / hrCA$5,401 / mo', 'location': 'Pittsburgh, PA ', 'season': '  Summer / 2024', 'company': 'Komatsu', 'details': '\nUndergrad (Senior)\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfcb')} successfully inserted into the database.
# {'href': 'https://smucker.wd5.myworkdayjobs.com/US_External_Careers?q=intern&ref=levels.fyi', 'salary': 'CA$29.1 / hrCA$5,049 / mo', 'location': 'Orville, OH ', 'season': '  Summer / 2024', 'company': 'The J.M. Smucker', 'details': '\nUndergrad (Junior)\nCA$4,064 Housing\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfcc')} successfully inserted into the database.
# {'href': 'https://www.1fort.com/careers/software-engineer-internship?ref=levels.fyi', 'salary': 'CA$27 / hrCA$4,696 / mo', 'location': 'New York City, NY ', 'season': '  Summer / 2024', 'company': '1Fort', 'details': '\nUndergrad (Senior)\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfcd')} successfully inserted into the database.
# {'href': 'https://en.avelios.com/jobs?ref=levels.fyi', 'salary': 'CA$25.6 / hrCA$4,438 / mo', 'location': 'Munich, Germany ', 'season': '  Summer / 2024', 'company': 'Avelios Medical', 'details': '\nUndergrad (Junior)\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfce')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'CA$23.31 / hrCA$4,041 / mo', 'location': 'Bruchsal, Germany ', 'season': '  Summer / 2024', 'company': 'SEW Eurodrive', 'details': '\nMasters\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfcf')} successfully inserted into the database.
# {'href': 'https://careers.antmicro.com/jobs/ai-internships/?ref=levels.fyi', 'salary': 'CA$15 / hrCA$2,583 / mo', 'location': 'Poznan, Poland ', 'season': '  Summer / 2024', 'company': 'Antmicro', 'details': '\nUndergrad (Junior)\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfd0')} successfully inserted into the database.
# {'href': 'https://boards.greenhouse.io/appier/jobs/5643194?ref=levels.fyi', 'salary': 'CA$14 / hrCA$2,348 / mo', 'location': 'Taipei, Taiwan ', 'season': '  Summer / 2024', 'company': 'Appier', 'details': '\nMasters\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfd1')} successfully inserted into the database.
# {'href': 'https://konfio.bamboohr.com/careers/936?ref=levels.fyi', 'salary': 'CA$3.13 / hrCA$542 / mo', 'location': 'Ciudad de Mexico, Mexico ', 'season': '  Summer / 2024', 'company': 'Konfio', 'details': '\nUndergrad (Junior)\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfd2')} successfully inserted into the database.
# {'href': 'https://jobs.lever.co/Zadara/ebe1dc23-1d74-4283-afe7-ba22d9a73fb5?ref=levels.fyi', 'salary': 'CA$2.34 / hrCA$406 / mo', 'location': 'Bengaluru, KA, India ', 'season': '  Summer / 2024', 'company': 'Zadara', 'details': '\nUndergrad (Senior)\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfd3')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'NA', 'location': 'Remote ', 'season': '  Summer / 2024', 'company': 'Yieldmo', 'details': '\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfd4')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'NA', 'location': 'North Andover, MA ', 'season': '  Summer / 2024', 'company': 'Visibility', 'details': '\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfd5')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'NA', 'location': 'Los Angeles, CA ', 'season': '  Summer / 2024', 'company': 'Tencent', 'details': '\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfd6')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'NA', 'location': 'San Francisco, CA ', 'season': '  Summer / 2024', 'company': 'Sixth Street', 'details': '\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfd7')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'NA', 'location': 'Lincoln, NE ', 'season': '  Summer / 2024', 'company': 'Sandhills', 'details': '\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfd8')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'NA', 'location': 'Beavercreek, OH ', 'season': '  Summer / 2024', 'company': 'Radiance Technologies', 'details': '\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfd9')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'NA', 'location': 'Remote ', 'season': '  Summer / 2024', 'company': 'Openmesh', 'details': '\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfda')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'NA', 'location': 'Lexington, MA ', 'season': '  Summer / 2024', 'company': 'MIT Lincoln Laboratory', 'details': '\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfdb')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'NA', 'location': 'Malta, NY ', 'season': '  Summer / 2024', 'company': 'GlobalFoundries', 'details': '\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfdc')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'NA', 'location': 'Birdsboro, PA ', 'season': '  Summer / 2024', 'company': 'Elbit Systems', 'details': '\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfdd')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'NA', 'location': 'Summer / 2024', 'company': 'Docugami', 'details': '\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfde')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'NA', 'location': 'London, United Kingdom ', 'season': '  Summer / 2024', 'company': 'Dataiku', 'details': '\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfdf')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'NA', 'location': 'Reading, United Kingdom ', 'season': '  Summer / 2024', 'company': 'Crowdstrike', 'details': '\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfe0')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'NA', 'location': 'Remote US ', 'season': '  Summer / 2024', 'company': 'Coding it forward', 'details': '\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfe1')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'NA', 'location': 'Lisbon, Portugal ', 'season': '  Summer / 2024', 'company': 'Capgemini', 'details': '\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfe2')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'NA', 'location': 'Boston, MA ', 'season': '  Summer / 2024', 'company': 'Bracebridge Capital', 'details': '\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfe3')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'NA', 'location': 'San Jose, CA ', 'season': '  Summer / 2024', 'company': 'Balbix', 'details': '\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfe4')} successfully inserted into the database.
# {'href': 'NA', 'salary': 'NA', 'location': 'Naperville, IL ', 'season': '  Summer / 2024', 'company': 'Alstom', 'details': '\n', 'timestamp': '2024_09_10_00-44-58', '_id': ObjectId('66dfced9294b2c895ef1cfe5')} successfully inserted into the database.

# %%
# print(soup.prettify())
